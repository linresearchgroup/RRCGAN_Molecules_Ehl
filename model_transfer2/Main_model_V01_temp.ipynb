# %%
# Strategy 1:
# Generate data after each epoch of training, if less than
# 10% error rate, and is a legit SMILES
# append to the real data
# Otherwise, append to fake data

# ADDING REINFORCEMENT MECHANISM
# Regenerate Normal sampling (define ranges), default: uniform

# IMPORTANT!!!!!!!!!!!!! DO NOT DROP DUPLICATE FOR RESULT .CSV

import warnings
warnings.filterwarnings('ignore')

import time
import os
import re
import pandas as pd
import random

import matplotlib as mpl
from matplotlib import rc, rcParams

import numpy as np
from numpy import ndarray

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import PCA
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error 
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import explained_variance_score
from scipy.stats import truncnorm

import multiprocessing
import pickle
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import (Input, Dropout, LSTM, Reshape, LeakyReLU,
                          Concatenate, ReLU, Flatten, Dense, Embedding,
                          BatchNormalization, Activation, SpatialDropout1D,
                          Conv2D, MaxPooling2D, UpSampling2D, Lambda)
from tensorflow.keras.models     import Model, load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses     import mse, binary_crossentropy
import tensorflow.keras.backend as K
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.metrics import  mean_squared_error as mse_keras
from tensorflow.keras.backend import argmax as argmax
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow import one_hot
from tensorflow.keras.models import Sequential 

from tensorflow.keras.utils import  to_categorical
from tensorflow import random as randomtf

from IPython.display import clear_output
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.lines as mlines
from   matplotlib.lines import Line2D
from   matplotlib.colors import ListedColormap
import matplotlib.ticker as tk

from progressbar import ProgressBar
import seaborn as sns

from chainer_chemistry.dataset.preprocessors import GGNNPreprocessor, construct_atomic_number_array
preprocessor = GGNNPreprocessor()
from rdkit import rdBase
rdBase.DisableLog('rdApp.error')
from rdkit import Chem

import ntpath
from scipy.stats import truncnorm

# import general file from utils as shared packages
import sys
sys.path.append("./../utils/")
from general import *

""" fix all the seeds,results are still slighthly different """
randomtf.set_seed(10)
os.environ['PYTHONHASHSEED'] = '10'
np.random.seed(420)
random.seed(123450)
from progressbar import ProgressBar
#gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=0.3667)
#session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1, gpu_options=gpu_options)
#tf.set_random_seed(1234)
#sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
#K.set_session(sess)
# Out:
# 2023-05-19 11:29:41.876778: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-19 11:29:41.942319: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-05-19 11:29:42.285136: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/cuda-11.2/lib64:
# 2023-05-19 11:29:42.285178: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/cuda-11.2/lib64:
# 2023-05-19 11:29:42.285182: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.4)
session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1, gpu_options=gpu_options)
tf.compat.v1.set_random_seed(1234)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
tf.compat.v1.keras.backend.set_session(sess)
# Out:
# 2023-05-19 11:29:43.937935: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-19 11:29:43.947289: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-19 11:29:43.951997: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-19 11:29:43.952200: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# WARNING:tensorflow:From /tmp/ipykernel_29492/24232086.py:5: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
# 2023-05-19 11:29:44.244945: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-19 11:29:44.245128: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-19 11:29:44.245201: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-19 11:29:44.245257: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9697 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
tf.compat.v1.keras.backend.clear_session()

# %%
# check the font !!!!!!!!!!!!!!!!!!!!!
# switch to Arial
# if not working: delet ~/.catch/matplotlib
plt.rcParams["font.family"] = "Arial"
plt.rcParams['ps.useafm'] = True
plt.rcParams['pdf.fonttype'] = 42
mpl.font_manager.FontManager()

rc('font', weight='bold')
fig, ax = plt.subplots(figsize=(5, 4))
plt.scatter([10, 55], [10, 55])
ax.tick_params(axis='both', length=0, width=1.5, colors='black', grid_alpha=0, labelsize=20)
plt.xlabel('!!!Ariaaaal', fontname='Arial', fontsize=50)
# Out:
# Text(0.5, 0, '!!!Ariaaaal')

# %%
tf.compat.v1.keras.backend.clear_session()
with open('./../data/trainingsets/train_regular_pubqc130K/tokenizer.pickle', 'rb') as f:
    tokenizer = pickle.load(f)
tokenizer[0] = ' '
with open('./../data/trainingsets/train_regular_pubqc130K/tokenizer_object.pickle', 'rb') as f:
    tokenizer_ = pickle.load(f)

# %%
with open('./../data/trainingsets/highgap_outliergen_trans1/image.pickle', 'rb') as f:
    X_smiles_gen, SMILES_gen, y_gen = pickle.load(f) 
    
with open('./../data/trainingsets/highgap_outliergen_trans1/image_train.pickle', 'rb') as f:
    X_smiles_train_gen, SMILES_train_gen, y_train_gen = pickle.load(f)
    
with open('./../data/trainingsets/highgap_outliergen_trans1/image_test.pickle', 'rb') as f:
    X_smiles_val_gen, SMILES_val_gen, y_val_gen = pickle.load(f)

# %%
y_gen.shape
# Out:
# (510,)

# %%
SMILES_gen = np.array (SMILES_gen)
y_gen = np.array (y_gen)

# %%
with open('./../data/trainingsets/highgap_pubqc/image.pickle', 'rb') as f:
    X_smiles_pubqc, SMILES_pubqc, y_pubqc = pickle.load(f) 
    
with open('./../data/trainingsets/highgap_pubqc/image_train.pickle', 'rb') as f:
    X_smiles_train_pubqc, SMILES_train_pubqc, y_train_pubqc = pickle.load(f) 
    
with open('./../data/trainingsets/highgap_pubqc/image_test.pickle', 'rb') as f:
    X_smiles_val_pubqc, SMILES_val_pubqc, y_val_pubqc = pickle.load(f)

# %%
y_pubqc.shape
# Out:
# (861,)

# %%
X_smiles = np.concatenate ((X_smiles_pubqc, X_smiles_gen), axis=0)
SMILES = np.concatenate ((SMILES_pubqc, SMILES_gen), axis=0)
y0 = np.concatenate ((y_pubqc, y_gen), axis=0)
print (y0.shape)
print (X_smiles.shape)
# Out:
# (1371,)
# (1371, 40, 27, 1)

# %%
X_smiles_train = np.concatenate ((X_smiles_train_pubqc, X_smiles_train_gen), axis=0)
SMILES_train = np.concatenate ((SMILES_train_pubqc, SMILES_train_gen), axis=0)
y_train0 = np.concatenate ((y_train_pubqc, y_train_gen), axis=0)
print (y_train0.shape)
print (X_smiles_train.shape)
# Out:
# (1096,)
# (1096, 40, 27, 1)

# %%
train_data = pd.DataFrame({})
train_data ['SMILES'] = SMILES_train
train_data ['gap'] = y_train0

# %%
train_data.to_csv('./temp.csv', index=False)

# %%
X_smiles_val = np.concatenate ((X_smiles_val_pubqc, X_smiles_val_gen), axis=0)
SMILES_val = np.concatenate ((SMILES_val_pubqc, SMILES_val_gen), axis=0)
y_val0 = np.concatenate ((y_val_pubqc, y_val_gen), axis=0)
print (y_val0.shape)
print (X_smiles_val.shape)
# Out:
# (275,)
# (275, 40, 27, 1)

# %%
# Standardized between 0 and 11
gap_min = 0
gap_max = 11
y_val   = (y_val0 -   gap_min) / (gap_max - gap_min)
y_train = (y_train0 - gap_min) / (gap_max - gap_min)

print (max(y_val))
print (max(y_train))

print (min(y_val))
print (min(y_train))
# Out:
# 1.248755909090909
# 1.5389282727272728
# 0.8638382727272728
# 0.8638871828946427

# %%
SMILES
# Out:
# array(['CCCCCCCC.', 'N#N.', 'C1CC1.', ..., 'CCCCC1C2CCC1C2C.',
#        'CCC(C)(C)CC(C)F.', 'CCC12CCCC3C1CCC32.'], dtype=object)

# %%
fig, ax = plt.subplots(figsize=(5, 4))

ax.tick_params(axis='both', length=4, width=2, colors='black', grid_alpha=0, labelsize=15)
[i.set_linewidth(2) for i in ax.spines.values()]
plt.xlabel('HOMO-LUMO gap (eV)', fontname='Arial', fontweight = 'bold', fontsize=15)
plt.ylabel('% of samples', fontname='Arial', fontweight = 'bold', fontsize=15)

sns.histplot (y_train0, color='red', label='train', stat='percent', kde=True, bins=50)
sns.histplot (y_val0, color='blue', label='test', stat='percent', kde=True, bins=50, alpha=0.5)
plt.legend()
plt.tight_layout()
plt.savefig('gap_val_train.jpeg', dpi=500)

# %%
""" models definition and extracting pretrained encoder and decoder """
encoder = load_model('./../data/nns/encoder_trans.h5')
decoder = load_model('./../data/nns/decoder_trans.h5')

class Config:
    
    def __init__(self):
        self.Filters = [256, 128, 64]
        self.genFilters = [128, 128, 128]
        self.upFilters = [(2, 2), (2, 2), (2, 2)]
        
config = Config()

## Generator 
z = Input(shape = (128, ))
y = Input(shape = (1, ))

h = Concatenate(axis = 1)([z, y])
h = Dense(1 * 1 * 128)(h)
R1 = Reshape([1, 1, 128])(h)
R2 = Reshape([1, 1, 128])(h)

for i in range(3):
    R1 = UpSampling2D(size = config.upFilters[i])(R1)
    C1 = Conv2D(filters = config.genFilters[i], 
               kernel_size = 2, 
               strides = 1, 
               padding = 'same')(R1)
    B1 = BatchNormalization()(C1)
    R1 = LeakyReLU(alpha=0.2)(B1)

for i in range(3):
    R2 = UpSampling2D(size = config.upFilters[i])(R2)
    C2 = Conv2D(filters = config.genFilters[i], 
               kernel_size = 2, 
               strides = 1, 
               padding = 'same')(R2)
    B2 = BatchNormalization()(C2)
    R2 = LeakyReLU(alpha=0.2)(B2)
    
R1 = Conv2D(1,
            kernel_size = 3,
            strides = 1,
            padding = 'valid',
            activation = 'tanh')(R1)
R2 = Conv2D(1,
            kernel_size = 3,
            strides = 1,
            padding = 'valid',
            activation = 'tanh')(R2)

generator = Model([z, y], [R1, R2])
print (generator.summary())

## Discriminator 
inp1 = Input(shape = [6, 6, 1])
inp2 = Input(shape = [6, 6, 1])

X1 = Concatenate()([inp1, inp2])
X = Flatten()(X1)
y2 = Concatenate(axis = 1)([X, y])
for i in range(3):
		y2 = Dense(64, activation = 'relu')(y2)
		y2 = LeakyReLU(alpha = 0.2)(y2)
		y2 = Dropout(0.2)(y2)

O_dis = Dense(1, activation = 'sigmoid')(y2)


discriminator = Model([inp1, inp2, y], O_dis)
discriminator.compile(loss = 'binary_crossentropy', optimizer = Adam(lr = 5e-5, beta_1 = 0.5))
print (discriminator.summary()) 

## Regressor
inp1 = Input(shape = [6, 6, 1])
inp2 = Input(shape = [6, 6, 1])

yr = Concatenate()([inp1, inp2])

tower0 = Conv2D(64, 1, padding = 'same')(yr)
tower1 = Conv2D(64, 1, padding = 'same')(yr)
tower1 = Conv2D(64, 3, padding = 'same')(tower1)
tower2 = Conv2D(32, 1, padding = 'same')(yr)
tower2 = Conv2D(32, 5, padding = 'same')(tower2)
tower3 = MaxPooling2D(3, 1, padding = 'same')(yr)
tower3 = Conv2D(32, 1, padding = 'same')(tower3)
h = Concatenate()([tower0, tower1, tower2, tower3])
h = ReLU()(h)
h = MaxPooling2D(2, 1, padding = 'same')(h)

for i in range(6):
    tower0 = Conv2D(64, 1, padding = 'same')(h)
    tower1 = Conv2D(64, 1, padding = 'same')(h)
    tower1 = Conv2D(64, 3, padding = 'same')(tower1)
    tower2 = Conv2D(32, 1, padding = 'same')(h)
    tower2 = Conv2D(32, 5, padding = 'same')(tower2)
    tower3 = MaxPooling2D(3, 1, padding = 'same')(h)
    tower3 = Conv2D(32, 1, padding = 'same')(tower3)
    h = Concatenate()([tower0, tower1, tower2, tower3])
    h = ReLU()(h)
    if i % 2 == 0 and i != 0:
        h = MaxPooling2D(2, 1, padding = 'same')(h)
h = BatchNormalization()(h)

yr = Flatten()(h)
o = Dropout(0.2)(yr)
o = Dense(128)(o)

o_reg = Dropout(0.2)(o)
o_reg = Dense(1, activation = 'sigmoid')(o_reg)

regressor = Model([inp1, inp2], o_reg)
regressor_top = Model([inp1, inp2], o)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2023-05-19 11:16:22.509550: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-19 11:16:22.509763: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-19 11:16:22.509828: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-19 11:16:22.510084: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-19 11:16:22.510168: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-19 11:16:22.510222: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-19 11:16:22.510314: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-19 11:16:22.510369: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-19 11:16:22.510410: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9697 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:01:00.0, compute capability: 8.6
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128)]        0           []
#
#  input_2 (InputLayer)           [(None, 1)]          0           []
#
#  concatenate (Concatenate)      (None, 129)          0           ['input_1[0][0]',
#                                                                   'input_2[0][0]']
#
#  dense (Dense)                  (None, 128)          16640       ['concatenate[0][0]']
#
#  reshape (Reshape)              (None, 1, 1, 128)    0           ['dense[0][0]']
#
#  reshape_1 (Reshape)            (None, 1, 1, 128)    0           ['dense[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 2, 2, 128)    0           ['reshape[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 2, 2, 128)   0           ['reshape_1[0][0]']
#
#  conv2d (Conv2D)                (None, 2, 2, 128)    65664       ['up_sampling2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 2, 2, 128)    65664       ['up_sampling2d_3[0][0]']
#
#  batch_normalization (BatchNorm  (None, 2, 2, 128)   512         ['conv2d[0][0]']
#  alization)
#
#  batch_normalization_3 (BatchNo  (None, 2, 2, 128)   512         ['conv2d_3[0][0]']
#  rmalization)
#
#  leaky_re_lu (LeakyReLU)        (None, 2, 2, 128)    0           ['batch_normalization[0][0]']
#
#  leaky_re_lu_3 (LeakyReLU)      (None, 2, 2, 128)    0           ['batch_normalization_3[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 4, 4, 128)   0           ['leaky_re_lu[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 4, 4, 128)   0           ['leaky_re_lu_3[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 4, 4, 128)    65664       ['up_sampling2d_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 4, 4, 128)    65664       ['up_sampling2d_4[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 4, 4, 128)   512         ['conv2d_1[0][0]']
#  rmalization)
#
#  batch_normalization_4 (BatchNo  (None, 4, 4, 128)   512         ['conv2d_4[0][0]']
#  rmalization)
#
#  leaky_re_lu_1 (LeakyReLU)      (None, 4, 4, 128)    0           ['batch_normalization_1[0][0]']
#
#  leaky_re_lu_4 (LeakyReLU)      (None, 4, 4, 128)    0           ['batch_normalization_4[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 8, 8, 128)   0           ['leaky_re_lu_1[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (None, 8, 8, 128)   0           ['leaky_re_lu_4[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 8, 8, 128)    65664       ['up_sampling2d_2[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 8, 8, 128)    65664       ['up_sampling2d_5[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 8, 8, 128)   512         ['conv2d_2[0][0]']
#  rmalization)
#
#  batch_normalization_5 (BatchNo  (None, 8, 8, 128)   512         ['conv2d_5[0][0]']
#  rmalization)
#
#  leaky_re_lu_2 (LeakyReLU)      (None, 8, 8, 128)    0           ['batch_normalization_2[0][0]']
#
#  leaky_re_lu_5 (LeakyReLU)      (None, 8, 8, 128)    0           ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 6, 6, 1)      1153        ['leaky_re_lu_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 6, 6, 1)      1153        ['leaky_re_lu_5[0][0]']
#
# ==================================================================================================
# Total params: 416,002
# Trainable params: 414,466
# Non-trainable params: 1,536
# __________________________________________________________________________________________________
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# None
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 6, 6, 1)]    0           []
#
#  input_4 (InputLayer)           [(None, 6, 6, 1)]    0           []
#
#  concatenate_1 (Concatenate)    (None, 6, 6, 2)      0           ['input_3[0][0]',
#                                                                   'input_4[0][0]']
#
#  flatten (Flatten)              (None, 72)           0           ['concatenate_1[0][0]']
#
#  input_2 (InputLayer)           [(None, 1)]          0           []
#
#  concatenate_2 (Concatenate)    (None, 73)           0           ['flatten[0][0]',
#                                                                   'input_2[0][0]']
#
#  dense_1 (Dense)                (None, 64)           4736        ['concatenate_2[0][0]']
#
#  leaky_re_lu_6 (LeakyReLU)      (None, 64)           0           ['dense_1[0][0]']
#
#  dropout (Dropout)              (None, 64)           0           ['leaky_re_lu_6[0][0]']
#
#  dense_2 (Dense)                (None, 64)           4160        ['dropout[0][0]']
#
#  leaky_re_lu_7 (LeakyReLU)      (None, 64)           0           ['dense_2[0][0]']
#
#  dropout_1 (Dropout)            (None, 64)           0           ['leaky_re_lu_7[0][0]']
#
#  dense_3 (Dense)                (None, 64)           4160        ['dropout_1[0][0]']
#
#  leaky_re_lu_8 (LeakyReLU)      (None, 64)           0           ['dense_3[0][0]']
#
#  dropout_2 (Dropout)            (None, 64)           0           ['leaky_re_lu_8[0][0]']
#
#  dense_4 (Dense)                (None, 1)            65          ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 13,121
# Trainable params: 13,121
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
np.max (y_train)
# Out:
# 1.5389282727272728

# %%
# Training the Regressor 
# latent vectors from trained Encoder, 
# last output of Encoder is concat. (O1, O2)
train_atoms_embedding, train_bonds_embedding, _ = encoder.predict([X_smiles_train], verbose=0)
atoms_embedding, bonds_embedding, _ = encoder.predict([X_smiles_train], verbose=0)
atoms_val, bonds_val, _ = encoder.predict([X_smiles_val], verbose=0)

# No training if the trained model is saved. 
try:
    regressor = load_model('./../data/nns/keep/regressor.h5')
    regressor_top = load_model('./../data/nns/keep/regressor_top.h5')
    regressor.compile(loss = 'mse', optimizer = Adam(1e-8))
    print (".h5 was read")
except:
    print ("no .h5 available")
    regressor.compile(loss = 'mse', optimizer = Adam(1e-8))
    pass
    
history = regressor.fit([atoms_embedding, bonds_embedding], 
              y_train,
              validation_data = ([atoms_val,
                                  bonds_val],
                                 y_val),
              batch_size = 2,
              epochs = 1,
              verbose = 1)
    
# Validating the regressor
# Train
pred_train = regressor.predict([atoms_embedding, bonds_embedding])
pred_train0 = pred_train*(gap_max-gap_min)+gap_min
print('Current R2 on Regressor for train data: {}'.format(r2_score(y_train0, pred_train0.reshape([-1]))))
mse_train = mean_squared_error(y_train0, pred_train0.reshape([-1]))
mae_train = mean_absolute_error(y_train0, pred_train0.reshape([-1]))

#print ('prediction on train: ', pred_train)
#print ('True train: ', y_train)

# Test
pred = regressor.predict([atoms_val, bonds_val])
pred0 = pred*(gap_max-gap_min) + gap_min
print('Current R2 on Regressor for test data: {}'.format(r2_score(y_val0, pred0.reshape([-1]))))
mse_val = mean_squared_error (y_val0, pred0.reshape([-1]))
mae_val = mean_absolute_error (y_val0, pred0.reshape([-1]))

#print ("prediction on test: ", pred )
#print ("True test values: ", y_val)

print ('Train MSE: {}, RMSE: {}, MAE: {}'.format (round(mse_train, 5), 
                                                  round(mse_train**0.5, 5), 
                                                  round(mae_train, 5)))
print ('Test MSE: {}, RMSE: {}, MAE: {}'.format (round(mse_val, 5), 
                                                  round(mse_val**0.5, 5), 
                                                  round(mae_val, 5)))
# Saving the currently trained models
regressor.save('./../data/nns/regressor_trans.h5')
regressor_top.save('./../data/nns/regressor_top_trans.h5')

# save the losses 
with open ('regressor_loss_0_150.csv', 'w') as f:
    for key in history.history.keys():
        f.write("%s,%s\n"%(key,history.history[key]))
# Out:
# 2023-05-19 11:16:24.040712: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8100
# 2023-05-19 11:16:24.424535: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# .h5 was read
# 2023-05-19 11:16:27.720890: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-05-19 11:16:27.721702: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7f2b8dd39980 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-05-19 11:16:27.721712: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2023-05-19 11:16:27.724156: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-05-19 11:16:27.762626: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-05-19 11:16:27.786014: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 548/548 [==============================] - 10s 7ms/step - loss: 0.0042 - val_loss: 0.0043
# 35/35 [==============================] - 0s 3ms/step
# Current R2 on Regressor for train data: -2.243126094370526
# 9/9 [==============================] - 0s 5ms/step
# Current R2 on Regressor for test data: -3.1607207199865686
# Train MSE: 0.46536, RMSE: 0.68218, MAE: 0.42829
# Test MSE: 0.52046, RMSE: 0.72143, MAE: 0.48368
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
plt.scatter(y_val, pred+0.05, )
plt.plot ([0.1, 1], [0.1, 1])

# %%
print (np.max(pred0))
print (np.max(y_train0))
print (np.max(pred_train0))
print (np.max(y_val0))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 print (np.max(pred0))
#       2 print (np.max(y_train0))
#       3 print (np.max(pred_train0))
#
# NameError: name 'pred0' is not defined

# %%
MAE_pred_des = np.round (mean_absolute_error(pred0, y_val0), 4)
print ("MAE_pred_des", MAE_pred_des)
# Fractioned MAE, more normalized
Fractioned_MAE_pred_des = 0
for pred, true in zip(pred0, y_val0):
        Fractioned_MAE_pred_des = Fractioned_MAE_pred_des +  abs(pred-true)/true
Fractioned_MAE_pred_des = Fractioned_MAE_pred_des/(pred0.shape[0])
print ("MAEF_pred_des", Fractioned_MAE_pred_des)
# Out:
# MAE_pred_des 0.3828
# MAEF_pred_des [0.07646773]

# %%
fig, ax = plt.subplots(figsize=(5, 4))
plt.plot(list(range(len(history.history['loss']))), 
         history.history['loss'], label='Training loss', linewidth=3,) 
plt.plot(list(range(len(history.history['val_loss']))), 
         history.history['val_loss'], label='Validation loss', linewidth=3,) 

ax.set_xlabel('Epochs', fontsize='20', fontname='Arial', fontweight='bold', labelpad=5)
ax.set_ylabel('Loss', fontsize='20', fontname='Arial', fontweight='bold', labelpad=5)

ax.tick_params(direction='out', length=5, width=3, colors='black', grid_alpha=1, labelsize='18')

[i.set_linewidth(2) for i in ax.spines.values()]


#plt.title ('per {}, rand {}'.format(per, rand))

#plt.ylim(0, 12)
#plt.xticks((1, 3, 5, 7, 9,  11));
#plt.yticks((1, 3, 5, 7, 9,  11));
plt.title('Regressor loss', fontsize=15, fontname='Arial', fontweight='bold', pad=10)
plt.legend(fontsize=15) 
plt.tight_layout()
plt.savefig("R_loss_0_100.png", dpi=300)

# %%
fig, ax = plt.subplots(figsize=(5, 4))
plt.rcParams["legend.markerscale"] = 1

plt.scatter (y_train0, pred_train0, color='red', label='Train', alpha=0.6, s=10)
plt.scatter ( y_val0, pred0, color='blue', label='Test', alpha=0.6, s=10)

plt.legend()

ax.set_xlabel('DFT gap (eV)', fontsize='20', fontname='Arial', fontweight='bold', labelpad=5)
ax.set_ylabel('Pred. gap (eV)', fontsize='20', fontname='Arial', fontweight='bold', labelpad=5)

ax.tick_params(direction='out', length=5, width=3, colors='black', 
               grid_alpha=1, labelsize='18')

[i.set_linewidth(3) for i in ax.spines.values()]
leg = plt.legend(title='Train: R$^2$={}, MAE={} \nTest: R$^2$={}, MAE={}'.\
           format(round(r2_score(y_train0, pred_train0.reshape([-1])), 2), 
                  round (mae_train, 2),
                  round (r2_score(y_val0, pred0.reshape([-1])), 2), 
                  round (mae_val, 2), ), framealpha=0, title_fontsize=10)
leg._legend_box.align = "left"

#plt.title ('per {}, rand {}'.format(per, rand))
plt.xlim(0, 3)
plt.ylim(0, 3)
#plt.xticks((1, 3, 5, 7, 9,  11));
#plt.yticks((1, 3, 5, 7, 9,  11));
plt.plot([0, 12], [0, 12], '--k', )#color='black')
plt.tight_layout()
plt.savefig('regressor_train_val.jpeg', dpi=300)
plt.rcParams["legend.markerscale"] = 1

# %%
np.max(pred_train0)
# Out:
# 10.321596

# %%
K.clear_session()

# %%
## Combined model 
def build_combined(z, y,
                   regressor,
                   regressor_top,
                   discriminator,
                   encoder,
                   decoder):
    discriminator.trainable = False
    regressor_top.trainable = False
    regressor.trainable = False
    encoder.trainable = False
    decoder.trainable = False
    
    atoms_emb, bonds_emb = generator([z, y])
    dec_embedding = Concatenate()([atoms_emb, bonds_emb])
    
    softmax_smiles, _ = decoder([dec_embedding])
    argmax_smiles = argmax (softmax_smiles, axis=2)
    argmax_smiles = Reshape([40])(argmax_smiles)
    smiles = one_hot(argmax_smiles, depth=27)
    smiles = Reshape([40, 27, 1])(smiles)
    latent_encoder_atom, latent_encoder_bond, _ = encoder ([smiles])
    
    y_pred = regressor([latent_encoder_atom, latent_encoder_bond])
    valid = discriminator([atoms_emb, bonds_emb, y])
    #print ('valid from comb', valid)

    combined = Model([z, y], [valid, y_pred])

    combined.compile(loss = ['binary_crossentropy',
                             'mse'], 
                     loss_weights = [0.01, 25.0], 
                     optimizer = Adam(5e-6, beta_1 = 0.5))
    
    return combined

combined = build_combined(z, y,
                          regressor,
                          regressor_top,
                          discriminator,
                          encoder,
                          decoder)

# %%
p = multiprocessing.Process()
""" Training RCGAN """
# loading pretrained models
regressor = load_model    ('./../data/nns/regressor.h5')
regressor_top = load_model('./../data/nns/regressor_top.h5')
#generator = load_model    ('./../data/nns/keep/generator.h5')
#discriminator = load_model ('./../data/nns/keep/discriminator.h5')
#combined = load_model ('./../data/nns/combined.h5')

regressor_top.trainable = False
regressor.trainable = False

# SMILES related information
max_gen_atoms = 9
bond_max = 9
MAX_NB_WORDS = 27
MAX_SEQUENCE_LENGTH = 40


epochs = 150
batch_size = 256
batches = y_train0.shape[0] // batch_size
threshold = 0.2 # defining accurate samples
reinforce_n = 50 # 5*reinforce_n = fake sampling
reinforce_sample = 1000 # how many samples generated for Reinforcement

# variable for storing generated data
G_Losses = []
D_Losses = []
R_Losses = []
D_Losses_real = []
D_Losses_fake = []

for e in range(epochs):
    start = time.time()
    D_loss = []
    G_loss = []
    R_loss = []
    D_loss_real = []
    D_loss_fake = []
    
    for b in range(batches):
        
        regressor_top.trainable = False
        regressor.trainable = False

        idx = np.arange(b * batch_size, (b + 1) * batch_size)
        # rearrange the samples 
        idx = np.random.choice(idx, batch_size, replace = False)
        
        x_smiles_train = X_smiles_train[idx] 
        batch_y = y_train[idx]
        
        batch_z = np.random.normal(0, 1, size = (batch_size, 128))
        
        atoms_embedding, bonds_embedding, _ = encoder.predict([x_smiles_train], verbose=0)
        dec_embedding = np.concatenate([atoms_embedding, bonds_embedding], axis = -1)
        
        gen_atoms_embedding, gen_bonds_embedding = generator.predict([batch_z, batch_y], verbose=0)
        
        gen_dec_embedding = np.concatenate([gen_atoms_embedding, gen_bonds_embedding], axis = -1)
        softmax_smiles = decoder.predict(gen_dec_embedding, verbose=0)[0]
        
        argmax_smiles = np.argmax(softmax_smiles, axis = 2)
        smiles = to_categorical(argmax_smiles, num_classes=27)
        SHAPE = list(smiles.shape) + [1]
        smiles = smiles.reshape(SHAPE)
        latent_encoder_atom, latent_encoder_bond, _ = encoder.predict([smiles], verbose=0)
        gen_pred = regressor.predict([latent_encoder_atom, latent_encoder_bond], verbose=0).reshape([-1])
        
        regressor.trainable = True
        r_loss = regressor.train_on_batch([atoms_embedding, bonds_embedding], batch_y)
        R_loss.append(r_loss)
        regressor.trainable = False

        discriminator.trainable = True
        # original was 3!
        d = 3
        #if b<100:
        #    d=1
        for _ in range(d):
            d_loss_real = discriminator.train_on_batch([atoms_embedding, bonds_embedding, batch_y],
                                                       [0.9 * np.ones((batch_size, 1))])
            d_loss_fake = discriminator.train_on_batch([gen_atoms_embedding, gen_bonds_embedding, batch_y],
                                                       [np.zeros((batch_size, 1))]) 

        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
        D_loss.append(d_loss)
        D_loss_real.append (d_loss_real)
        D_loss_fake.append (d_loss_fake)
        discriminator.trainable = False
        
        regressor_top.trainable = False
        regressor.trainable = False

        #for _ in range(d):
        g_loss = combined.train_on_batch([batch_z, batch_y], [0.9 * np.ones((batch_size, 1)), batch_y])
        
        G_loss.append(g_loss[0])
    
    D_Losses.append(np.mean(D_loss))
    D_Losses_real.append(np.mean(D_loss_real))
    D_Losses_fake.append(np.mean(D_loss_fake))
    G_Losses.append(np.mean(G_loss))
    R_Losses.append(np.mean(R_loss))
    
    print('====')
    print('Current epoch: {}/{}'.format((e + 1), epochs))
    print ('D Loss Real: {}'.format(np.mean(D_loss_real)))
    print ('D Loss Fake: {}'.format(np.mean(D_loss_fake)))
    print('D Loss: {}'.format(np.mean(D_loss)))
    print('G Loss: {}'.format(np.mean(G_loss)))
    print('R Loss: {}'.format(np.mean(R_loss)))
    print('====')
    print()

    
    # Reinforcement
    gen_error = []
    gen_smiles = []
    gen_valid_smiles = []
    gen_X_atoms = []
    gen_X_bonds = []
    predcv_AE_latent = []
    embeddings = []
    sample_ys = []
    valid_smiles_index = []
    for _ in range(reinforce_sample):
        sample_y = np.random.uniform(gap_min, gap_max, size = [1, ])
        sample_y = np.round(sample_y, 4)
        sample_y = (sample_y - gap_min) / (gap_max - gap_min)
        sample_ys.append(sample_y)

        sample_z = np.random.normal(0, 1, size = (1, 128))

        sample_atoms_embedding, sample_bonds_embedding = generator.predict([sample_z, sample_y], verbose=0)
        embeddings.append((sample_atoms_embedding, sample_bonds_embedding))
        
        dec_embedding = np.concatenate([sample_atoms_embedding, sample_bonds_embedding], axis = -1)
        softmax_smiles = decoder.predict(dec_embedding, verbose=0)[0]
        argmax_smiles = np.argmax(softmax_smiles, axis = 2).reshape([-1])
        smiles = to_categorical(argmax_smiles, num_classes=27)
        SHAPE = [1] + list(smiles.shape) + [1]
        smiles = smiles.reshape(SHAPE)
        c_smiles = ''
        for s in argmax_smiles:
            c_smiles += tokenizer[s]
        c_smiles = c_smiles.rstrip()
        
        gen_smiles.append(c_smiles)
        latent_encoder_atom, latent_encoder_bond, _ = encoder.predict([smiles], verbose=0)
        reg_pred = regressor.predict([latent_encoder_atom, latent_encoder_bond], verbose=0)
        
        pred, desire = reg_pred[0][0], sample_y[0]
        gen_error.append(round (np.abs((pred - desire) / desire), 5)) #!!!!!!!!!!!!! chenge it to desire

        
    gen_error = np.asarray(gen_error).reshape(-1, 1)
    # two validity defined: 

    # without sanitizing: valid 0    
    valid = 0
    valid0 = 0
    idx_ = []
    idx0_ = []
    preds_can = []
    for iter_, smiles in enumerate(gen_smiles):
        if ' ' in smiles[:-1]:
            continue
        m  = Chem.MolFromSmiles(smiles[:-1], sanitize=True)
        m0 = Chem.MolFromSmiles(smiles[:-1], sanitize=False)
        if m0 is not None:
            valid0 += 1
            idx0_.append(iter_)
        if m is not None:
            #if len(construct_atomic_number_array(m)) <= 60:
            valid += 1
            idx_.append(iter_)
            #try:
            gen_smiles [iter_] = Chem.MolToSmiles(m, canonical=True)
            smiles_can = Chem.MolToSmiles(m, canonical=True)
            smiles_can_dot = smiles_can + '.'
            X_smiles0 = tokenizer_.texts_to_sequences([smiles_can_dot])
            X_smiles1 = pad_sequences(X_smiles0, maxlen = 40, padding = 'post')
            X_smiles2 = to_categorical(X_smiles1, num_classes=27)
            latent_encoder_atom, latent_encoder_bond, _ = encoder.predict(X_smiles2, verbose=0)
            pred_can = regressor.predict([latent_encoder_atom, latent_encoder_bond], verbose=0).reshape([-1])
            #pred_can = pred_can*11
            preds_can.append(pred_can[0])
            print (Chem.MolToSmiles(m, canonical=True))
            print ("gap_des", sample_ys[iter_])
            print ("error", gen_error[iter_])
            #except:
                #pass
    idx_ = np.asarray(idx_)

    idx0_ = np.asarray(idx0_)
    preds_can = np.array (preds_can).reshape(-1, 1)
    #print('gen error before correction:', gen_error [idx_])
    sample_ys_ = np.array (sample_ys)
    gen_error [idx_] = [(abs(i-j)/j) for i,j in zip(preds_can, sample_ys_[idx_])] 
    #print('gen error after correction:', gen_error [idx_])
    validity = [gen_smiles[jj] for jj in idx0_ ]
    validity = pd.DataFrame(validity)
    validity = validity.drop_duplicates()

    validity_sanitize = [gen_smiles[jj] for jj in idx_ ]
    validity_sanitize = pd.DataFrame(validity_sanitize)
    validity_sanitize = validity_sanitize.drop_duplicates()

    if (e + 1) % 100 == 0:
        reinforce_n += 10

    # invalid smiles:
    fake_indices1 = np.setdiff1d(np.arange(reinforce_sample), np.asarray(idx_))
    fake_indices2 = np.intersect1d(np.where(gen_error > threshold)[0], idx_)
    fake_indices = np.concatenate ((fake_indices1, fake_indices2))
    fake_indices = np.random.choice(fake_indices, reinforce_n * 5, replace = False)

    real_indices_ = np.intersect1d(np.where(gen_error <= threshold)[0], idx_)
    sample_size =  len(real_indices_)
    real_indices = np.random.choice(real_indices_, sample_size, replace = False)
    
    # Activating Reinforcement 
    if e >= 5:
        discriminator.trainable = True
        regressor_top.trainable = False
        regressor.trainable = False
        for real_index in real_indices:
            #real_latent = regressor_top.predict([embeddings[real_index][0], embeddings[real_index][1]])
            _ = discriminator.train_on_batch([embeddings[real_index][0], 
                                              embeddings[real_index][1], 
                                              sample_ys[real_index]],
                                             [1 * np.ones((1, 1))])

        for fake_index in fake_indices:
            #fake_latent = regressor_top.predict([embeddings[fake_index][0], embeddings[fake_index][1]])
            _ = discriminator.train_on_batch([embeddings[fake_index][0], 
                                              embeddings[fake_index][1] , 
                                              sample_ys[fake_index]],
                                             [np.zeros((1, 1))])
        discriminator.trainable = False

    # ==== #
    try:
        print('Currently valid SMILES (No chemical_beauty and sanitize off): {}'.format(valid0))
        print('Currently valid SMILES Unique (No chemical_beauty and sanitize off): {}'.format(len(validity)))
        print('Currently valid SMILES Sanitized: {}'.format(valid))
        print('Currently valid Unique SMILES Sanitized: {}'.format(len(validity_sanitize)))
        print('Currently satisfying SMILES: {}'.format(len(real_indices_)))
        print('Currently unique satisfying generation: {}'.format(len(np.unique(np.array(gen_smiles)[real_indices_]))))
        #print('Gen Sample is: {}, for {}'.format(c_smiles, sample_y))
        #print('Predicted val: {}'.format(reg_pred))
        print('====')
        print()
    except:
        pass
    
    if (e + 1) % 5 == 0:
        plt.close()
        fig, ax = plt.subplots(figsize = (12, 10))
        ax.tick_params(axis='both', which='major', labelsize=30)
        plt.plot(G_Losses, color='blue')
        plt.plot(D_Losses, color='red')
        plt.xlabel('epochs', fontsize=35)
        plt.ylabel('loss', fontsize=35)
        mpl.rcParams['axes.linewidth'] = 2.5
        #plt.plot(R_Losses)
        plt.legend(['G Loss', 'D Loss'], fontsize=30)
        plt.savefig("G_D_losses{}.png".format (e+1))
    

    n_unique = len(np.unique(np.array(gen_smiles)[real_indices_]))
    n_valid = valid
    if valid > 450 and n_unique > 350:
        print('Criteria has satisified, training has ended')
        break

    end = time.time()
    print ("time for current epoch: ", (end - start))

    tf.compat.v1.keras.backend.clear_session()
with open('GAN_loss.pickle', 'wb') as f:
    pickle.dump((G_Losses, D_Losses, R_Losses), f)

# Saving the currently trained models
#regressor.save('regressor.h5')
#regressor_top.save('regressor_top.h5')
generator.save('./../data/nns/generator.h5')
discriminator.save('./../data/nns/discriminator.h5')
combined.save('./../data/nns/combined.h5')

p.start()
pred_can
p.join()
print ('Done')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# ====
# Current epoch: 1/150
# D Loss Real: 0.34670412626819336
# D Loss Fake: 0.026630428957680898
# D Loss: 0.1866672776129371
# G Loss: 1.3040879243525907
# R Loss: 0.0016870156008129318
# ====
#
# CCCC(CCCNN=O)C1CN1
# gap_des [0.06169091]
# error [8.3273]
# C=NCCCCCCCCC
# gap_des [0.17487273]
# error [2.22147]
# CCC(O)NC1CC1CNNC=CO
# gap_des [0.72721818]
# error [0.20591]
# C#CCC(CC)CON1C=C1C
# gap_des [0.66192727]
# error [0.11651]
# CC1CCCNCCN1NO
# gap_des [0.43666364]
# error [0.23874]
# COCC(CCOO)OO
# gap_des [0.30042727]
# error [0.78994]
# CC1(N)CCNCCCNC1C1CNC=CN1
# gap_des [0.05837273]
# error [8.79928]
# COOCC1CCCC(CCNO)COOS1
# gap_des [0.38990909]
# error [0.60222]
# NC=CNCNCC1[C]CN1
# gap_des [0.05579091]
# error [6.42244]
# COCCCCC1OCCC(C)C(CCCCCOCO)CO1
# gap_des [0.21370909]
# error [2.79621]
# CCC(N)NC=CCCCNC(C)CNC
# gap_des [0.79374545]
# error [0.26651]
# ONCCCC1CCCCCCNN1O
# gap_des [0.82731818]
# error [0.14788]
# NCC1COC(N(O)OOO)OCC(=O)N1
# gap_des [0.26632727]
# error [1.43675]
# C.CC(NN)NN(NN)NCCCCCCCCN
# gap_des [0.4615]
# error [0.34508]
# CC1NC=CSCC(Cl)=CO1
# gap_des [0.14527273]
# error [2.47889]
# CCC1=CC=CC(CCCN)COC1(C)C
# gap_des [0.65009091]
# error [0.0709]
# CCCNC1OC(O)(CC)CCCCCC1C
# gap_des [0.79090909]
# error [0.0076]
# CCCCCCCCC(N)CN
# gap_des [0.05747273]
# error [11.28134]
# COCCCCCCCCCC=NNOC
# gap_des [0.01959091]
# error [28.57593]
# CCCCC=CCCNC
# gap_des [0.80989091]
# error [0.33735]
# C=C(C)CC(CC)CC
# gap_des [0.1513]
# error [2.54179]
# CCCOCCCCC1CC12CCCC2C
# gap_des [0.83464545]
# error [0.00176]
# COOC1(CCNOCNNNCCCCO)CC1=O
# gap_des [0.29073636]
# error [1.57147]
# CCC(N)CCC1CCCO1
# gap_des [0.17468182]
# error [3.3705]
# OCCCCCCCCCN=NNNCNCO
# gap_des [0.85611818]
# error [0.27221]
# CCCC=CCOCCCCCC1CCCCC1
# gap_des [0.62856364]
# error [0.09842]
# CC=CNNCCCOCC
# gap_des [0.1576]
# error [2.89937]
# CCCOCC1COC(OC)OCC=C1O
# gap_des [0.73016364]
# error [0.1213]
# CCC1CNNCCCCCCCCCCOC1C
# gap_des [0.0993]
# error [6.11641]
# NC1=[SH]C1CCCCNOCCO
# gap_des [0.07363636]
# error [6.86182]
# CCNCC(COONOCO)OC
# gap_des [0.37819091]
# error [0.82967]
# CC1CCNCNC1
# gap_des [0.43760909]
# error [0.40381]
# CCCCCCCCCC1CCCC1CCCCCCC
# gap_des [0.788]
# error [0.12412]
# CSCOOCNCN
# gap_des [0.31062727]
# error [0.9853]
# CCCCCCCCCCCC(COCO)OCCO
# gap_des [0.65382727]
# error [0.22296]
# C=C1C(OOO)CC2C1OC(OO)OOON2C=O
# gap_des [0.88024545]
# error [0.3141]
# CCCCC(O)CN=CCCCC(C)(C)O
# gap_des [0.33664545]
# error [0.96606]
# OOCCOCCCCCCCC=NN1C=N1
# gap_des [0.48468182]
# error [0.18173]
# O=CCCC(CCCC(=O)OO)OCC1CC1
# gap_des [0.54021818]
# error [0.25585]
# CCC1CCC=NNC(C)CC(O)NNN=N1
# gap_des [0.40189091]
# error [0.223]
# Currently valid SMILES (No chemical_beauty and sanitize off): 60
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 60
# Currently valid SMILES Sanitized: 40
# Currently valid Unique SMILES Sanitized: 40
# Currently satisfying SMILES: 10
# Currently unique satisfying generation: 10
# ====
#
# time for current epoch:  233.32663989067078
# ====
# Current epoch: 2/150
# D Loss Real: 0.3325708288933344
# D Loss Fake: 0.005614139612132553
# D Loss: 0.16909248425273346
# G Loss: 1.2885592237186894
# R Loss: 0.0016840319601922399
# ====
#
# COCC1CCCCS1
# gap_des [0.67670909]
# error [0.1639]
# CC(CO)NNCCN(CNNN)COO
# gap_des [0.65583636]
# error [0.08688]
# C=NCC(C)CCCSNC=O
# gap_des [0.81223636]
# error [0.47263]
# CCCCCNC1NCNCNC1SCNN
# gap_des [0.48805455]
# error [0.29106]
# COCCCN(C)CN=NCC(C)C
# gap_des [0.64348182]
# error [0.08627]
# CCCCN(C)OC(=N)CO
# gap_des [0.60540909]
# error [0.00552]
# COCCCCCNC(CO)NNNN
# gap_des [0.69296364]
# error [0.10278]
# CCCCCCN=CC1C=C1C(N)CCCNCN
# gap_des [0.1402]
# error [2.37262]
# COC(CO)CCCCCCC=CNCCCO
# gap_des [0.14469091]
# error [3.41502]
# C#CNCCCCCCCC
# gap_des [0.35113636]
# error [0.7288]
# CCOC1CCOCCCCC(C=O)CC1
# gap_des [0.14423636]
# error [3.52661]
# CCC1CCNNC1C1CCCCOC1CO
# gap_des [0.55465455]
# error [0.33265]
# CCCCCCNNCC=C(O)NC
# gap_des [0.89354545]
# error [0.27525]
# C=CC(C=CNCNOCCO)=COOOO
# gap_des [0.34950909]
# error [0.08788]
# CCCCSCCCC
# gap_des [0.53744545]
# error [0.16483]
# CCCC1(O)CN2NNNC(CC)C1(C)C2C
# gap_des [0.60956364]
# error [0.02476]
# O=C1CCC1CC=C1CCNCCNN1
# gap_des [0.39373636]
# error [0.2608]
# CCCCC1CCOCCC1CCCCOO
# gap_des [0.93122727]
# error [0.24399]
# CNN1CCCNCC1C1CCCCN1C=N
# gap_des [0.51916364]
# error [0.15868]
# CCCCCCCCCCC(COCC)OC
# gap_des [0.32751818]
# error [1.43217]
# C=C(CC)CCC(C)CC(C)CCC
# gap_des [0.24727273]
# error [1.37643]
# CCCOONC1CCCCOCCCOC1C
# gap_des [0.79509091]
# error [0.12862]
# CON1PCN1NOOC(C)=O
# gap_des [0.18215455]
# error [2.16478]
# CCOCNC#CC(O)CC(C)CNCCO
# gap_des [0.63445455]
# error [0.11117]
# CCC(CC)NCCC1CCCCC1
# gap_des [0.24701818]
# error [1.4325]
# C=C(CC)CCCCCCC(CCCC)NN
# gap_des [0.55612727]
# error [0.02875]
# C=CCCC=CC1CCCCCCCC1C
# gap_des [0.67432727]
# error [0.15986]
# CCC(N)NC(COC)C1COCC1C=C(C)O
# gap_des [0.39650909]
# error [0.6263]
# CCCOCC1CCCCC(N)COCCC1
# gap_des [0.2583]
# error [1.73079]
# CCOC(C)CCCCC(C)CCC(O)CN
# gap_des [0.13606364]
# error [4.46112]
# CCCC1OCCOCCOC1CC
# gap_des [0.58299091]
# error [0.31905]
# OCC1CCCNCCCCNCNNCC1
# gap_des [0.79968182]
# error [0.19042]
# CCC1=NN=C1CCCCC(C)CC
# gap_des [0.50940909]
# error [0.11704]
# CC(O)OC(C=NNN(O)CO)=CCCCCCO
# gap_des [0.06508182]
# error [5.80767]
# NN=CCC=CCCCCC(CO)CCNN
# gap_des [0.3935]
# error [0.177]
# CCCCCCCCCCCC1CCCCC1
# gap_des [0.10031818]
# error [7.74503]
# CCCC(O)CCCCCC(NCOC)C(C)CC
# gap_des [0.53456364]
# error [0.33896]
# COCOCCNCCOCCCO
# gap_des [0.77418182]
# error [0.02523]
# CCCc1ccc(C)cc1NN
# gap_des [0.56643636]
# error [0.16065]
# CCCOCCNNCC(CNC)C(O)O
# gap_des [0.08593636]
# error [7.04212]
# CCC(C)CC1CCCC1OC(C)C(C)C
# gap_des [0.11645455]
# error [6.06571]
# OCCC1C=CCCCCCC1O
# gap_des [0.57145455]
# error [0.02682]
# CCC(CCNN=CCO)CN=O
# gap_des [0.46697273]
# error [0.16267]
# CCC(CCCO)COC(CC)CCN
# gap_des [0.50563636]
# error [0.35034]
# CC1=C=CCCCCC1C1=CCCC1
# gap_des [0.54054545]
# error [0.07809]
# Currently valid SMILES (No chemical_beauty and sanitize off): 79
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 79
# Currently valid SMILES Sanitized: 45
# Currently valid Unique SMILES Sanitized: 45
# Currently satisfying SMILES: 18
# Currently unique satisfying generation: 18
# ====
#
# time for current epoch:  222.3867049217224
# ====
# Current epoch: 3/150
# D Loss Real: 0.3335898081605561
# D Loss Fake: 0.007584387504839865
# D Loss: 0.170587097832698
# G Loss: 1.2904207350839163
# R Loss: 0.0016811522160283322
# ====
#
# CCCCCCCCC(C)C
# gap_des [0.7469]
# error [0.16566]
# CC.N=NN
# gap_des [0.22562727]
# error [1.59981]
# CCCOOOOCC(C)O
# gap_des [0.45957273]
# error [0.48413]
# CCCCC1CC(C)C(N)C1CC
# gap_des [0.39397273]
# error [0.77908]
# COCCCCCCNCNOCOC
# gap_des [0.6721]
# error [0.09437]
# C=CCOCC(CCCCCF)NCCCC#N
# gap_des [0.57476364]
# error [0.14448]
# CC(=N)C(C)C
# gap_des [0.03553636]
# error [15.82008]
# OC1CCOC1
# gap_des [0.91597273]
# error [0.17622]
# O=COCCCCC=CC1CCC=C=[SH]1
# gap_des [0.25977273]
# error [0.39509]
# NOOC=C(NCCNOOO)C1CCN1
# gap_des [0.46594545]
# error [0.11445]
# O=NC=CC(O)CNCN(CO)NO
# gap_des [0.07793636]
# error [4.9042]
# CN[PH](=O)NPCO
# gap_des [0.19953636]
# error [2.14192]
# NNC1CC1O
# gap_des [0.86784545]
# error [0.1979]
# O=C1C=CC=CCCCCCNN=C1
# gap_des [0.01282727]
# error [31.99745]
# CC=CCC=C(CC=CC)CCSSS
# gap_des [0.44747273]
# error [0.18363]
# CCCCCCCCCC1=CC=NC=CN1OCCC
# gap_des [0.19794545]
# error [1.11016]
# CCC(C)=POO
# gap_des [0.20045455]
# error [1.33552]
# CCCCCCC1CC1CCC
# gap_des [0.34863636]
# error [1.52235]
# CCCCN1C(CC)CC1C1CCCC1
# gap_des [0.04176364]
# error [15.43929]
# CC1CCON(C2=CC=C2CO)C1(C)O
# gap_des [0.86314545]
# error [0.3093]
# C#CC(CC(=S)S)NNN=C
# gap_des [0.13011818]
# error [2.03544]
# CCCNC=CCC(C)C
# gap_des [0.40608182]
# error [0.33943]
# COC1CCC=CC=CCOCNCC1S
# gap_des [0.83417273]
# error [0.45373]
# OONC(OO)PCC1CC1
# gap_des [0.04702727]
# error [14.90274]
# NNCNCC=O
# gap_des [0.67186364]
# error [0.15073]
# C=CCCC=CC(O)COOC
# gap_des [0.95271818]
# error [0.43139]
# CCN(C)NNNCCN=CCN(C)C
# gap_des [0.40669091]
# error [0.41952]
# NC1CCCCC1CCCO
# gap_des [0.64253636]
# error [0.16955]
# C=[PH](CC(O)CC)C(C)(C)CC
# gap_des [0.11338182]
# error [4.69915]
# CCCCCCCCC
# gap_des [0.85436364]
# error [0.36618]
# CCCCC(CO)OCCO
# gap_des [0.72599091]
# error [0.01362]
# CONCC(C)CC1C(C)C1CCC(C)C
# gap_des [0.33528182]
# error [1.15824]
# CCC1CCCCC1(C)CCCNC(C)=N
# gap_des [0.17952727]
# error [2.60601]
# CC1(N)CCNCCN1
# gap_des [0.51493636]
# error [0.36966]
# CCCNC=CNCCOCC
# gap_des [0.3291]
# error [0.64982]
# CN(NNNNCNNCCO)C1CCCC1
# gap_des [0.58460909]
# error [0.07763]
# NCCNN1C=CN(N=CCO)S1
# gap_des [0.02457273]
# error [18.77941]
# C.CCCCSCCCS
# gap_des [0.62658182]
# error [0.0843]
# CCCC=C(CCCC=O)CSC
# gap_des [0.59326364]
# error [0.11393]
# CCC1(C=O)CCCOCC(CO)O1
# gap_des [0.07546364]
# error [7.2394]
# CC(C)C=C1OC1CCC(O)NCCCO
# gap_des [0.21215455]
# error [1.98461]
# C=CCCC=CCCCCCCCCCC
# gap_des [0.85441818]
# error [0.29578]
# Currently valid SMILES (No chemical_beauty and sanitize off): 75
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 75
# Currently valid SMILES Sanitized: 42
# Currently valid Unique SMILES Sanitized: 42
# Currently satisfying SMILES: 11
# Currently unique satisfying generation: 11
# ====
#
# time for current epoch:  219.1382565498352
# ====
# Current epoch: 4/150
# D Loss Real: 0.33665150641531183
# D Loss Fake: 0.01020486672675453
# D Loss: 0.17342818657103318
# G Loss: 1.3073750089332101
# R Loss: 0.0016791325184552601
# ====
#
# CNC1COOCC1(C)O
# gap_des [0.47730909]
# error [0.42422]
# CCCC1=CC=CC=CO1
# gap_des [0.8886]
# error [0.46498]
# CCCCOOCOCC(CCCC)CCCO
# gap_des [0.06778182]
# error [10.35016]
# NN[SH]1CCSS1
# gap_des [0.30090909]
# error [0.62295]
# CCC(C)NC(C)CNC
# gap_des [0.20540909]
# error [2.63244]
# OCc1ccccc1C1CCCCNN1NNO
# gap_des [0.54491818]
# error [0.01751]
# CCC1=CN=C1
# gap_des [0.7547]
# error [0.25507]
# CONNCCCCCNNN
# gap_des [0.44731818]
# error [0.51675]
# CCC1NCCC(N)OCCCCCO1
# gap_des [0.3367]
# error [1.10314]
# ONONCCCCC=C1CC1OO
# gap_des [0.10049091]
# error [4.06889]
# SC1SC=CCSCS1
# gap_des [0.94866364]
# error [0.50655]
# C=NCC1CSC=CC=CC=C(N)C1C
# gap_des [0.34044545]
# error [0.15659]
# C=C=NC1=CCCCCCC1N
# gap_des [0.87892727]
# error [0.4974]
# C=C1CCCCC(=S)C(F)CC1
# gap_des [0.4723]
# error [0.04489]
# CCCOCCCN
# gap_des [0.54166364]
# error [0.13214]
# CCCCNCC(N)NC(=N)CO
# gap_des [0.77717273]
# error [0.10369]
# [CH][CH]C(O)CO
# gap_des [0.30844545]
# error [0.36741]
# COSSC[SH](O)SO
# gap_des [0.88254545]
# error [0.47412]
# CCC(C)OCCCOC
# gap_des [0.04647273]
# error [13.18616]
# C=C(CCNNN(C=O)CO)NNNNO
# gap_des [0.18380909]
# error [1.50232]
# O=[SH]C1SSCC(SS)P[SH]1O
# gap_des [0.41985455]
# error [0.05032]
# CCCCC1(C)C=S(CC)CCC1
# gap_des [0.47387273]
# error [0.03111]
# CCCCCCSCCCC[SH](C)CC(C)CO
# gap_des [0.54754545]
# error [0.15129]
# CC1OCCCN1CO
# gap_des [0.29934545]
# error [1.22281]
# NCCCNN1CNCN1
# gap_des [0.62889091]
# error [0.03395]
# O=C1NNNNCC12C1=CC=CC=CC(O)=C12
# gap_des [0.1395]
# error [1.93271]
# CN1N=NNN=C1c1c2noc1C=CC=CN=C2
# gap_des [0.45699091]
# error [0.10717]
# CCCCCCCNC=NCC
# gap_des [0.62940909]
# error [0.1006]
# C=C(COC)C(=N)NCC
# gap_des [0.81184545]
# error [0.34736]
# OCCCC1CN=CC(O)C=C1OCCC(O)O
# gap_des [0.93572727]
# error [0.47]
# CN(CCC=N)CCCC1CCN1CS
# gap_des [0.34249091]
# error [0.31163]
# CCCCCCC(C)CCCCC
# gap_des [0.07224545]
# error [9.51343]
# CC1CC(S)C(CO)C(S)CS1
# gap_des [0.05598182]
# error [8.84979]
# CCCCN1CCCCCC(C)NCC1
# gap_des [0.17395455]
# error [2.9269]
# CSCCSCSNNCCSNON
# gap_des [0.65321818]
# error [0.20365]
# CCCC1SC1CSC
# gap_des [0.58114545]
# error [0.02032]
# C=C(NCCOCCCC)NCC(C)NNNN
# gap_des [0.50581818]
# error [0.05509]
# CCC1CC2CC(CCCC2C)NCN1
# gap_des [0.50627273]
# error [0.28006]
# CCCOOCCCOCOC
# gap_des [0.80629091]
# error [0.06819]
# CCC(NCNNN(C)C)=C(C)N(C)C
# gap_des [0.39561818]
# error [0.3994]
# C=CCCCC(O)CC=CNNNC
# gap_des [0.54730909]
# error [0.03118]
# CC1=C=COCCCC1C
# gap_des [0.14437273]
# error [2.82546]
# C=C1NCCC=C=CC=NCCCNNN1
# gap_des [0.38378182]
# error [0.12382]
# Currently valid SMILES (No chemical_beauty and sanitize off): 78
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 78
# Currently valid SMILES Sanitized: 43
# Currently valid Unique SMILES Sanitized: 43
# Currently satisfying SMILES: 12
# Currently unique satisfying generation: 12
# ====
#
# time for current epoch:  221.69208788871765
# ====
# Current epoch: 5/150
# D Loss Real: 0.3393330024780283
# D Loss Fake: 0.013342819773313109
# D Loss: 0.17633791112567068
# G Loss: 1.3214669279430225
# R Loss: 0.0016747721477078752
# ====
#
# CCCC(C)CNCNCNCC=NNC1C(N)C1CC
# gap_des [0.62210909]
# error [0.04895]
# COc1ssc1CC=CCC1=CC=CC=CN1
# gap_des [0.18768182]
# error [0.90575]
# CC1CCN1C1=CCc2[nH]ccsc1cc2CO
# gap_des [0.97761818]
# error [0.58055]
# C=CCCNCCNCNCCCNC
# gap_des [0.03447273]
# error [16.00474]
# CCNCC#CCCC=C(C)C
# gap_des [0.88381818]
# error [0.34378]
# C=CCCCCCCC(C)NNNN
# gap_des [0.40851818]
# error [0.48962]
# CC[P+]([O-])=CCCCNC(O)CCCC=O
# gap_des [0.82644545]
# error [0.45538]
# CCCN1CCCCSC1
# gap_des [0.8794]
# error [0.29984]
# CCCCSSCCC#[SH]
# gap_des [0.49384545]
# error [0.03376]
# O=CCCCCCCC=COP
# gap_des [0.20470909]
# error [1.77378]
# C=C(CC)NNCOCC
# gap_des [0.48069091]
# error [0.26144]
# OCCCCCNCCC1CCCC1N=CCCOCOO
# gap_des [0.29500909]
# error [0.83065]
# C=C[SH]1SCC1SCC
# gap_des [0.61677273]
# error [0.33649]
# CC=CCC=CCOCC
# gap_des [0.32149091]
# error [0.3023]
# CCCCCCC1CCSCC1C
# gap_des [0.26756364]
# error [1.39548]
# C.CCCCNNCCC
# gap_des [0.2773]
# error [1.48145]
# CCOCNNNCC1CCC1CCCCOC
# gap_des [0.99287273]
# error [0.35484]
# CCOCCCCCCCCCO
# gap_des [0.56079091]
# error [0.45837]
# CCC1CCCCCCCCC(=O)OCO1
# gap_des [0.33576364]
# error [1.11511]
# CC1CCCCN1C
# gap_des [0.47796364]
# error [0.24626]
# CCCCCC(NC)SCCCC
# gap_des [0.329]
# error [0.85287]
# CCCONNCN
# gap_des [0.52478182]
# error [0.3569]
# CNCCCCCCCCCCOCO
# gap_des [0.94026364]
# error [0.25242]
# CCCC(=O)N=O
# gap_des [0.24210909]
# error [1.09259]
# CCCOC1CCOCC=COCC1CO
# gap_des [0.02691818]
# error [21.77659]
# CC(N)NNNCC1CC1
# gap_des [0.49729091]
# error [0.2981]
# CCOC(C)=NCC=CC(CCO)CNO
# gap_des [0.33371818]
# error [0.52954]
# CCCCCCCCNC(=O)CSC
# gap_des [0.41386364]
# error [0.57916]
# CCCCCCC
# gap_des [0.58220909]
# error [0.28143]
# CCCC(CC)CO
# gap_des [0.20925455]
# error [2.95488]
# CSCC1C[C]1C
# gap_des [0.82553636]
# error [0.4295]
# CCN1CCCC1C=C(CNNNCCCO)OC
# gap_des [0.00207273]
# error [283.32876]
# C=C1CCCCCC(C)C(O)NN1
# gap_des [0.94063636]
# error [0.34083]
# OOC1=C2OC(=C3N=CC2=CC=CO3)C=C1
# gap_des [0.98267273]
# error [0.57086]
# CCCC(=O)ONNNCC(C)(CCNOC)OO
# gap_des [0.75297273]
# error [0.26628]
# COCOC1CNCNCCC1CC(C)C
# gap_des [0.27058182]
# error [1.62391]
# NCCCCC=NN
# gap_des [0.71954545]
# error [0.09596]
# Currently valid SMILES (No chemical_beauty and sanitize off): 69
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 69
# Currently valid SMILES Sanitized: 37
# Currently valid Unique SMILES Sanitized: 37
# Currently satisfying SMILES: 5
# Currently unique satisfying generation: 5
# ====
#
# time for current epoch:  215.93382716178894
# ====
# Current epoch: 6/150
# D Loss Real: 0.3427700311089483
# D Loss Fake: 0.01757906452957361
# D Loss: 0.18017454781926098
# G Loss: 1.3270333170314919
# R Loss: 0.0016836405108606326
# ====
#
# CCNCc1[nH]ccccc2nc1-2
# gap_des [0.53347273]
# error [0.17482]
# C=C1C2CCCC=CCC2C1CC(C)C
# gap_des [0.27508182]
# error [1.29064]
# C=CCCNCC
# gap_des [0.22067273]
# error [1.58899]
# CC1C(C)C12C=C2CCCCCCCO
# gap_des [0.19989091]
# error [1.91683]
# CCCC1CCCCC2CC1C1=CCC12N
# gap_des [0.1997]
# error [2.22798]
# CCCC(C)CNC
# gap_des [0.63903636]
# error [0.05872]
# C#CCC(CC)C1CCNC1NCCCNOCC
# gap_des [0.91931818]
# error [0.30507]
# CCCOCC=C(O)CC
# gap_des [0.96555455]
# error [0.33124]
# CCCC=[SH]CC=CO
# gap_des [0.62395455]
# error [0.35126]
# CNCCC=CCCC=CCCCNN
# gap_des [0.70581818]
# error [0.2513]
# CCC(CO)OC
# gap_des [0.10715455]
# error [5.31827]
# CCCCC1CCCCCC2CCCCC12
# gap_des [0.45468182]
# error [0.89858]
# CC1CCC#CCCSC2C=C2CSCCC1
# gap_des [0.93827273]
# error [0.51556]
# CNC(N)C[SH](C)[SH]1C=N1
# gap_des [0.86437273]
# error [0.40902]
# C=CNNCN=NC1C=CC=CNC(N)C1
# gap_des [0.76689091]
# error [0.47074]
# COCCCN=NN=C1CC1C
# gap_des [0.03981818]
# error [9.46211]
# CCN=CCOCCCOCCO
# gap_des [0.12498182]
# error [3.99246]
# CSC1=[SH]C2C=C1CCCCSS2
# gap_des [0.6354]
# error [0.54138]
# CNC(N)COCOCN
# gap_des [0.06460909]
# error [11.21444]
# C=C1CCN=CC12C=C1CC12
# gap_des [0.4058]
# error [0.16267]
# CC1C=CC=CC=CCCCCCNC=CC1
# gap_des [0.49961818]
# error [0.03771]
# C=CCCCC1CCCCC2CCC2N1
# gap_des [0.74140909]
# error [0.23536]
# CCCSCC=NN
# gap_des [0.23324545]
# error [1.2596]
# O=[PH](O)CNCCCCCNCNCCCO
# gap_des [0.26972727]
# error [1.34563]
# CCCN(C)CCCCCN
# gap_des [0.67144545]
# error [0.05239]
# Currently valid SMILES (No chemical_beauty and sanitize off): 49
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 49
# Currently valid SMILES Sanitized: 25
# Currently valid Unique SMILES Sanitized: 25
# Currently satisfying SMILES: 2
# Currently unique satisfying generation: 2
# ====
#
# time for current epoch:  219.02977633476257
# ====
# Current epoch: 7/150
# D Loss Real: 0.35666464564304995
# D Loss Fake: 0.031616504706784294
# D Loss: 0.19414057517491712
# G Loss: 1.316065428049668
# R Loss: 0.0016731769577622557
# ====
#
# CSPPC=[SH]CCCSS
# gap_des [0.55607273]
# error [0.33955]
# COCCCC(C)=N
# gap_des [0.42127273]
# error [0.26892]
# CC1(O)CCCCOC1O
# gap_des [0.89356364]
# error [0.1273]
# N=C=CCCNC(=O)O
# gap_des [0.56503636]
# error [0.04325]
# N=CS1=C(C2NC2=O)SC=C1
# gap_des [0.02170909]
# error [18.88959]
# ClC1CCCNNC12CCCCCN2
# gap_des [0.88232727]
# error [0.26518]
# OCC1CC=CCC=C2C=C2S1
# gap_des [0.44336364]
# error [0.32638]
# COC(CO)OCNCCC=O
# gap_des [0.38831818]
# error [0.79058]
# CCCCOCCOCCNCCCCCOC
# gap_des [0.41518182]
# error [0.81391]
# CCC(C)CCPPCP[SH](OO)C(C)O
# gap_des [0.63152727]
# error [0.09316]
# C#CC1OCCCCC2=CC=C1C2
# gap_des [0.26760909]
# error [1.14628]
# CCCCCCOCCOCCC1OC1CCCCC
# gap_des [0.90047273]
# error [0.10857]
# CCC#N
# gap_des [0.02871818]
# error [23.39832]
# N#CC1CCCCCCS1
# gap_des [0.18013636]
# error [2.32805]
# COC1=CCCCC=CCCC1
# gap_des [0.49917273]
# error [0.12066]
# CCCOOCCSC
# gap_des [0.54697273]
# error [0.15201]
# C=CCCCCC[SH]=CCNCCOC
# gap_des [0.84259091]
# error [0.458]
# NNCCCCCCCNCCCCCO
# gap_des [0.20539091]
# error [2.32317]
# C=CCC=O
# gap_des [0.65168182]
# error [0.11619]
# O=C(O)CCOCCP
# gap_des [0.52904545]
# error [0.26392]
# CCCCC1(CC)CCCC1C
# gap_des [0.09380909]
# error [7.85335]
# CCC1CCCC(S)C(C)CCC=[SH]C1
# gap_des [0.16595455]
# error [1.63303]
# CCCCCC=CCCC1COCCCC1=O
# gap_des [0.24120909]
# error [1.24166]
# CNC(C)(C)CCC=N
# gap_des [0.72774545]
# error [0.15988]
# CCCCCCN=CC1CC(CC)N1
# gap_des [0.69310909]
# error [0.13093]
# CCOOCC(N)CC(CC)C1=CC=CC=CC(C)C1O
# gap_des [0.62776364]
# error [0.061]
# Currently valid SMILES (No chemical_beauty and sanitize off): 53
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 53
# Currently valid SMILES Sanitized: 26
# Currently valid Unique SMILES Sanitized: 26
# Currently satisfying SMILES: 10
# Currently unique satisfying generation: 10
# ====
#
# time for current epoch:  227.26910185813904
# ====
# Current epoch: 8/150
# D Loss Real: 0.3739001157779049
# D Loss Fake: 0.052819313207002366
# D Loss: 0.2133597144924536
# G Loss: 1.2899916845819224
# R Loss: 0.0016792833308491334
# ====
#
# CCNCCNCCCCCCN
# gap_des [0.86703636]
# error [0.26696]
# CC(O)CCCCCC1CCC=CCCC1
# gap_des [0.72268182]
# error [0.17016]
# CNCCCC1CC1O
# gap_des [0.85830909]
# error [0.26188]
# C=CC1=CC=CC1
# gap_des [0.32350909]
# error [0.49419]
# OCCC1CCCOCCC1
# gap_des [0.92010909]
# error [0.26006]
# CCCN1CC1OC
# gap_des [0.86307273]
# error [0.27935]
# CCC(C)CNC(C)CO
# gap_des [0.85299091]
# error [0.14557]
# CC(=N)N(NO)OCCC(C)N
# gap_des [0.59685455]
# error [0.03896]
# CC(CCSCCON)OOO
# gap_des [0.14748182]
# error [4.00654]
# CCCCOCCC
# gap_des [0.14216364]
# error [3.69836]
# CCC(C=CNOC)CCCOC(=O)C(C)N
# gap_des [0.94385455]
# error [0.35784]
# CCCSS
# gap_des [0.56327273]
# error [0.20394]
# CCC#CC(C)CCC
# gap_des [0.28946364]
# error [1.51668]
# CCC1CCCCCC1
# gap_des [0.96694545]
# error [0.37814]
# CN1C=C(NNN)C12CC=CSN2
# gap_des [0.7996]
# error [0.43121]
# COC1CCCCCC1
# gap_des [0.87332727]
# error [0.0755]
# CCCCNOCO
# gap_des [0.23239091]
# error [2.07534]
# C=CCC1CSC1C1CCCSSC1C
# gap_des [0.06788182]
# error [6.47964]
# CC(OP)OC1CO1
# gap_des [0.3944]
# error [0.98775]
# CC=NCNCSCCSC1COCSC1
# gap_des [0.39334545]
# error [0.50404]
# CCOCC=CC=C1C=C1
# gap_des [0.60334545]
# error [0.40071]
# CSSCC1=CC(C)C(CSCCCCC=O)C1
# gap_des [0.96936364]
# error [0.55138]
# CN1COC=CCCNC=CCCCC1=O
# gap_des [0.78325455]
# error [0.42657]
# SC1CCCC=CC=CC=C1C1=CC=COC1
# gap_des [0.73845455]
# error [0.32144]
# CCCCN=CCCCCCSCCSCCCCC#N
# gap_des [0.56513636]
# error [0.11378]
# CCC(C)CCC1=CC=CC=CCCCCC=C1
# gap_des [0.05920909]
# error [7.36376]
# COCCCCCC1SCCC=CN1OCCO
# gap_des [0.83546364]
# error [0.32448]
# CCCCC1=C2OC(=O)C=CC=C2C=CC=C1
# gap_des [0.83467273]
# error [0.50894]
# CCCCCSCSCC=CC1CC1CCCN
# gap_des [0.09415455]
# error [4.84967]
# C=C(COCC)OC(O)CO
# gap_des [0.78342727]
# error [0.13419]
# CCSCCOCCCCCNCOOCCO
# gap_des [0.45825455]
# error [0.43938]
# Currently valid SMILES (No chemical_beauty and sanitize off): 64
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 64
# Currently valid SMILES Sanitized: 31
# Currently valid Unique SMILES Sanitized: 31
# Currently satisfying SMILES: 11
# Currently unique satisfying generation: 11
# ====
#
# time for current epoch:  222.4135763645172
# ====
# Current epoch: 9/150
# D Loss Real: 0.3891742910451935
# D Loss Fake: 0.06329594537219851
# D Loss: 0.22623511820869602
# G Loss: 1.2774631686256703
# R Loss: 0.0016740529023556282
# ====
#
# CCC=C=CCOCCC
# gap_des [0.22186364]
# error [1.07951]
# CCC=C(C)C=C1CNCCC(C)=NNC1
# gap_des [0.35436364]
# error [0.09533]
# COCC1C2CCC(C)Oc3cccn3OC1C2
# gap_des [0.64016364]
# error [0.18751]
# COCCCCCCCCCCO
# gap_des [0.48306364]
# error [0.13967]
# CCOCSC(C)OCCOCCCCO
# gap_des [0.95512727]
# error [0.29052]
# CO[PH](CC=COO)=C(O)CO
# gap_des [0.26336364]
# error [1.37294]
# CSCSSCSCCSS
# gap_des [0.89376364]
# error [0.44045]
# CC(C)COO
# gap_des [0.14694545]
# error [2.81182]
# CSCCCCCC[C](C)C
# gap_des [0.05763636]
# error [7.36045]
# CCCCC(CCCNCCNCC)OC
# gap_des [0.95774545]
# error [0.28318]
# CC[SH]1OC1CN
# gap_des [0.78293636]
# error [0.10523]
# C#CC1=C2C=C1C=CC=CN=CC=C2OO
# gap_des [0.04592727]
# error [4.53296]
# O=CCCCCCO
# gap_des [0.31655455]
# error [0.60754]
# C[C]1CNCCCCC12CCCC2
# gap_des [0.82283636]
# error [0.32561]
# COCCCCCN=CC1CNC(CS)C1
# gap_des [0.48144545]
# error [0.11272]
# CCCCC=C1C=CNC1
# gap_des [0.62072727]
# error [0.28085]
# CCC1CC#CCC(C=CCOC)CCC1
# gap_des [0.71259091]
# error [0.19412]
# CCCNNCSCCC1CC=C1OCC=O
# gap_des [0.6148]
# error [0.17463]
# CNCCCC1=CCCCCNSCCNSC1
# gap_des [0.24989091]
# error [0.6237]
# OCC1NCC2CCC1=CC=CCCNN2
# gap_des [0.74116364]
# error [0.2232]
# OCCCCCC1NCNCSCS1
# gap_des [0.04471818]
# error [13.70505]
# CCC(=CCNC(=O)O)OCC(C)NNCCOCO
# gap_des [0.63415455]
# error [0.00479]
# COCN=C1C[SH]1C
# gap_des [0.03642727]
# error [14.34442]
# CC1CCNNCC1CCCCCCC=O
# gap_des [0.38038182]
# error [0.62547]
# Currently valid SMILES (No chemical_beauty and sanitize off): 56
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 56
# Currently valid SMILES Sanitized: 24
# Currently valid Unique SMILES Sanitized: 24
# Currently satisfying SMILES: 5
# Currently unique satisfying generation: 5
# ====
#
# time for current epoch:  224.7446310520172
# ====
# Current epoch: 10/150
# D Loss Real: 0.3913674090363553
# D Loss Fake: 0.0720532227685486
# D Loss: 0.23171031590245197
# G Loss: 1.286630430083344
# R Loss: 0.0016710381971217765
# ====
#
# CC(O)CNOOC1(O)CC1COOCOOO
# gap_des [0.64372727]
# error [0.07]
# CCCCSC(C[O])CCCOC(C)O
# gap_des [0.62093636]
# error [0.02413]
# CNC1=C(NN)C2=CCCC2C(CCN)=CS1
# gap_des [0.67650909]
# error [0.35036]
# CCCCCOC1CN(OCC(C)C)CCNN1
# gap_des [0.908]
# error [0.19499]
# CCCSCOC1C[SH]1(=O)CCSC=O
# gap_des [0.19594545]
# error [1.72551]
# CCOCCCOCCOCCS
# gap_des [0.63026364]
# error [0.03371]
# NCCNNNNOCNO
# gap_des [0.68399091]
# error [0.07935]
# C=CC1CCCCC(C=N)C1C
# gap_des [0.83428182]
# error [0.2702]
# CCC1=C2C3=C(C)C=CC=CC=CC4=CC4C1=C32
# gap_des [0.69476364]
# error [0.32681]
# CCSCCSNC=O
# gap_des [0.15846364]
# error [2.66061]
# NCC1OC1CCC(N)C1CCC12C=CC=N2
# gap_des [0.38507273]
# error [0.60336]
# OCC1CC=CCN1C1CCCCC1
# gap_des [0.69189091]
# error [0.1389]
# CCCCCCC
# gap_des [0.7718]
# error [0.1453]
# CCC(C=C1CC(CC)C1=N)CO
# gap_des [0.36717273]
# error [0.41425]
# C#CC(C)C1C(COC)CC1SC
# gap_des [0.38552727]
# error [0.48783]
# CCCC1OCC(=O)CN1C(O)CC1CCCO1
# gap_des [0.2479]
# error [1.34557]
# CCNCCCCOCCCO
# gap_des [0.81229091]
# error [0.1423]
# OC1CCCS1
# gap_des [0.9362]
# error [0.29697]
# CC1C=NC=CC=CC=N1
# gap_des [0.22620909]
# error [1.16262]
# ClCCCCC1CCCCCCCCNN1
# gap_des [0.11250909]
# error [4.89341]
# C.C1N=NOCN1
# gap_des [0.07117273]
# error [9.30898]
# Currently valid SMILES (No chemical_beauty and sanitize off): 56
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 56
# Currently valid SMILES Sanitized: 21
# Currently valid Unique SMILES Sanitized: 21
# Currently satisfying SMILES: 8
# Currently unique satisfying generation: 8
# ====
#
# time for current epoch:  226.40785312652588
# ====
# Current epoch: 11/150
# D Loss Real: 0.4006964284296773
# D Loss Fake: 0.08649536866496726
# D Loss: 0.24359589854732228
# G Loss: 1.2818182007126186
# R Loss: 0.0016692281261441895
# ====
#
# CCC#CCCCN
# gap_des [0.23108182]
# error [1.89306]
# C1=CC2CCCCC1CCC2
# gap_des [0.7321]
# error [0.27064]
# CC1=C2CC=CCCC(O)C=CN12
# gap_des [0.07918182]
# error [4.98856]
# C=CCC1CCC[C](C=C)ONC(OC)OCC1
# gap_des [0.77556364]
# error [0.29051]
# C#CCCC1OC=NCC=C1CSC
# gap_des [0.2192]
# error [1.01245]
# O=CC=CN=CC=NO
# gap_des [0.98839091]
# error [0.72063]
# CCCCC1SCCPPC1CCl
# gap_des [0.86911818]
# error [0.31895]
# CCCOCC1CCCSC(CO)OC1
# gap_des [0.89499091]
# error [0.19902]
# C=C(CCOCCC(N)O)NN(O)OO
# gap_des [0.71731818]
# error [0.05555]
# C=CCC(CC)COCOCCCCON
# gap_des [0.605]
# error [0.09306]
# COCC1CCCSCC1C
# gap_des [0.99699091]
# error [0.39944]
# CCC1CCCN(OC)C1
# gap_des [0.69876364]
# error [0.03409]
# CCC1=C(CSC=S)C=CC=CCC1
# gap_des [0.04181818]
# error [9.03976]
# C=CC1NC(CCCN)C1CC(N)CO
# gap_des [0.56322727]
# error [0.13424]
# NCCCCC1CC=CC=CCCCCCS1
# gap_des [0.77921818]
# error [0.29898]
# CN(C)CC1CCNC1N
# gap_des [0.12574545]
# error [3.91273]
# CC=CC1C[SH]=CC1C
# gap_des [0.03015455]
# error [13.1207]
# CCOCCCCCOCC
# gap_des [0.85047273]
# error [0.06139]
# CC(C)CCCC=C1C=CCN=C1
# gap_des [0.32110909]
# error [0.2578]
# CCC(=O)C1SCCCCNNC1CC
# gap_des [0.32961818]
# error [0.72287]
# C=CCOCCCCCCCC1CCC1
# gap_des [0.94355455]
# error [0.22942]
# [C]C[C](NCC1CCNN1C)NNC
# gap_des [0.27564545]
# error [0.76127]
# COC(Cc1cnoc1)OCCCCSS
# gap_des [0.2821]
# error [0.67501]
# Currently valid SMILES (No chemical_beauty and sanitize off): 54
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 54
# Currently valid SMILES Sanitized: 23
# Currently valid Unique SMILES Sanitized: 23
# Currently satisfying SMILES: 6
# Currently unique satisfying generation: 6
# ====
#
# time for current epoch:  228.0070607662201
# ====
# Current epoch: 12/150
# D Loss Real: 0.4125055415186905
# D Loss Fake: 0.096818083078389
# D Loss: 0.25466181229853974
# G Loss: 1.282473549750692
# R Loss: 0.001667230389168675
# ====
#
# CC(C)CCCCC(C)CCCC(C)CO
# gap_des [0.29083636]
# error [1.70134]
# CCCC1C=CC1CCOCCCCOC
# gap_des [0.97121818]
# error [0.39239]
# C#CCC1CCCCCC1
# gap_des [0.39442727]
# error [0.72582]
# CC(=CC1CN1C)CO
# gap_des [0.19877273]
# error [1.71929]
# CCCCC(C)OOCC
# gap_des [0.70405455]
# error [0.00279]
# CCCCNNP(O)OO
# gap_des [0.71503636]
# error [0.14808]
# CCCCN1CC1OCOCOO
# gap_des [0.23290909]
# error [2.01049]
# S=C=CSC1=CCCC1CNC1C=CNN1
# gap_des [0.91465455]
# error [0.63064]
# NC1NNCC2CCC3=C1CCNNC32
# gap_des [0.63869091]
# error [0.25849]
# CC=COCC=NCCNN
# gap_des [0.32438182]
# error [0.58032]
# CC#CCCCCC1=CC=CC=CC=C1C
# gap_des [0.51413636]
# error [0.09092]
# CCCC1CCCC(CCC)C1CC
# gap_des [0.03795455]
# error [22.08648]
# CNCCCCCOCOOCCCCCCF
# gap_des [0.99826364]
# error [0.29705]
# CCCCC(N)(COCONC=CO)C1OC1CC
# gap_des [0.48434545]
# error [0.44569]
# CCCCNCCCCC=C(C)CCC
# gap_des [0.22826364]
# error [1.68452]
# C[C](N)NCC1CO1
# gap_des [0.78483636]
# error [0.22472]
# CCCCC1CC(C)(O)C1=CO
# gap_des [0.22844545]
# error [1.52242]
# CSC(O)=CCOS
# gap_des [0.00138182]
# error [399.09029]
# CCC(CNCOCC(C)OC)OC
# gap_des [0.63819091]
# error [0.16958]
# CNCCCC1=C2C=C(C=CN=CCSN=CC=C1)S2
# gap_des [0.08566364]
# error [3.48138]
# CSCOCCOCCOCOCCOO
# gap_des [0.40641818]
# error [0.90469]
# CNC=CC=[SH]CCNCOC
# gap_des [0.32304545]
# error [0.10645]
# N#CC[SH]=NCNCSCO
# gap_des [0.57513636]
# error [0.14721]
# C=C1C=CCCCC(OCC)=N1
# gap_des [0.53992727]
# error [0.14771]
# Currently valid SMILES (No chemical_beauty and sanitize off): 57
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 57
# Currently valid SMILES Sanitized: 24
# Currently valid Unique SMILES Sanitized: 24
# Currently satisfying SMILES: 7
# Currently unique satisfying generation: 7
# ====
#
# time for current epoch:  224.91643285751343
# ====
# Current epoch: 13/150
# D Loss Real: 0.42161422161664364
# D Loss Fake: 0.11232918296639183
# D Loss: 0.26697170229151773
# G Loss: 1.2839378893087452
# R Loss: 0.0016693124299585495
# ====
#
# OCCC1=C2C=C1SSSSC=CC=CCS2
# gap_des [0.73139091]
# error [0.5751]
# CCCNNC=C(CC)CCNO
# gap_des [0.25713636]
# error [1.20411]
# CCCCCCCC
# gap_des [0.92842727]
# error [0.29581]
# CC=C=CC(C)C
# gap_des [0.71030909]
# error [0.26022]
# COC1CCCCC1C1CC1CC1C=C1
# gap_des [0.40337273]
# error [0.51328]
# C=C(OCC)C(O)=CCC
# gap_des [0.18407273]
# error [1.85163]
# CC=CCCSCC1NC(NCN=S)C1CO
# gap_des [0.96672727]
# error [0.66908]
# CC(C)CCNCCC(O)CO
# gap_des [0.97484545]
# error [0.29602]
# CCC1CCC(OC)C(SC)S1
# gap_des [0.9327]
# error [0.36069]
# CC=C(CCC)CCO
# gap_des [0.61061818]
# error [0.04617]
# CC(=O)C(C)N1NNCCC1CN=O
# gap_des [0.44982727]
# error [0.27505]
# NOCCONCC=O
# gap_des [0.18609091]
# error [2.52906]
# CC(O)C(C)CC(O)NO
# gap_des [0.85646364]
# error [0.17849]
# CCC(O)CN
# gap_des [0.76097273]
# error [0.19327]
# Currently valid SMILES (No chemical_beauty and sanitize off): 46
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 46
# Currently valid SMILES Sanitized: 14
# Currently valid Unique SMILES Sanitized: 14
# Currently satisfying SMILES: 6
# Currently unique satisfying generation: 6
# ====
#
# time for current epoch:  224.73082208633423
# ====
# Current epoch: 14/150
# D Loss Real: 0.4219136491489871
# D Loss Fake: 0.11681584556753509
# D Loss: 0.2693647473582611
# G Loss: 1.287561274237103
# R Loss: 0.0016652500897461485
# ====
#
# CNC1=NC=CC2C(C)C2C1
# gap_des [0.1187]
# error [2.59311]
# C=CCC1CCCC=CCOC1CCCCN
# gap_des [0.53113636]
# error [0.01429]
# NCC1CCCON1
# gap_des [0.73594545]
# error [0.15139]
# CCCCCCOCOCN(CC)CCCOCC
# gap_des [0.91792727]
# error [0.23148]
# COC1C2CNCONCCCCCC(OO)OP1NC2
# gap_des [0.95399091]
# error [0.27033]
# C#CC1=C(C=C(C)C)C(CCCCNCC)=C1
# gap_des [0.17011818]
# error [1.59944]
# NN=C1NCCCC1=[SH]C=C=CCCO
# gap_des [0.9459]
# error [0.67759]
# CCCCCCCCCCCC1CC(C)CCC1CCC
# gap_des [0.04904545]
# error [17.60439]
# C#CCC(CC)C(CC(C)C(CC)CCCO)OC
# gap_des [0.94867273]
# error [0.30056]
# C=CCCC1CC1C#CN
# gap_des [0.40899091]
# error [0.47305]
# CCCCOCC1OCC(OCNNCOCC(C)CC)O1
# gap_des [0.89104545]
# error [0.10359]
# CO[PH]1(OC)CCOCCNCCCCC1C
# gap_des [0.35244545]
# error [1.13216]
# CCC1=CC2=C(S2)C(CO)CNNCCNC1C
# gap_des [0.70323636]
# error [0.25481]
# N[SH]1CCCCCCS1
# gap_des [0.39613636]
# error [0.37963]
# CC1CC=CC2=CCC2=CC=CC=CCCCC1
# gap_des [0.84172727]
# error [0.36384]
# CCCCCCCNN=CC1CCCC(CCCN)CCC1SC
# gap_des [0.32815455]
# error [0.78544]
# C=CN(NC)SOCCC1C=CN=C1
# gap_des [0.48410909]
# error [0.26673]
# COCC(CN)CCC#CN
# gap_des [0.56618182]
# error [0.26976]
# CC1CSCCCC1CC(=N)O
# gap_des [0.54923636]
# error [0.05996]
# CSN1[C]NN1
# gap_des [0.06473636]
# error [7.1851]
# CSCSSCC1SC=[SH]CC1C
# gap_des [0.28512727]
# error [0.23676]
# NC1CCCSC1CO
# gap_des [0.51699091]
# error [0.04389]
# O=C1C=CN=CN2CCC(O)=CCC2CC1NO
# gap_des [0.08950909]
# error [4.34667]
# C=CC(CC=O)=C1CC(C#N)C1C
# gap_des [0.05772727]
# error [6.40035]
# Currently valid SMILES (No chemical_beauty and sanitize off): 42
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 42
# Currently valid SMILES Sanitized: 24
# Currently valid Unique SMILES Sanitized: 24
# Currently satisfying SMILES: 6
# Currently unique satisfying generation: 6
# ====
#
# time for current epoch:  223.59934306144714
# ====
# Current epoch: 15/150
# D Loss Real: 0.4332627900988583
# D Loss Fake: 0.1280330496565731
# D Loss: 0.28064791987771576
# G Loss: 1.2754347975127363
# R Loss: 0.0016618060912028099
# ====
#
# CCCC=CC=CC=CCCCCO
# gap_des [0.81340909]
# error [0.52808]
# CCCC1CN(CC(CO)CCCO)N(O)N1C
# gap_des [0.11331818]
# error [5.31701]
# COCCCCC1CC2CCC=CC=CC21
# gap_des [0.43158182]
# error [0.2247]
# CC=C=C1CC1N(C)CS1(N=N)C=C1O
# gap_des [0.29522727]
# error [0.14249]
# C=C1NC2SCC=CC(=CCC#N)C12S
# gap_des [0.61455455]
# error [0.49717]
# CCC1SC2COC[SH]1C(CC)S2
# gap_des [0.25693636]
# error [1.34948]
# CCCC1=CC=C2NC=CC=C2C=C1
# gap_des [0.8451]
# error [0.50345]
# CCC1C=CCCC=CNCC=C1
# gap_des [0.08979091]
# error [3.47011]
# C=C(CCSC)SCCSSCSS
# gap_des [0.77099091]
# error [0.55381]
# CCC(OC(C)O)C(COC=O)OC
# gap_des [0.85726364]
# error [0.17208]
# C=C1C(CCO)C1(C=N)CC
# gap_des [0.93994545]
# error [0.49593]
# CC(C)CC(CCCO)CCCC1CCCC1
# gap_des [0.2276]
# error [2.81626]
# CC1CCC=CS(=O)C(O)C(F)CCC1
# gap_des [0.75848182]
# error [0.42996]
# OC1CCCC2C=C2S1
# gap_des [0.24919091]
# error [0.96611]
# CCC1=CCSCC2SC12
# gap_des [0.32068182]
# error [0.35577]
# CCCCN1CCOOON(NC(C)CC)C1C
# gap_des [0.17224545]
# error [2.89188]
# CCOC1CCCCCC(C)CCC1
# gap_des [0.73824545]
# error [0.20007]
# CCC(CC)CCCCCCCC=O
# gap_des [0.82901818]
# error [0.27205]
# C1CCCCCCCCCCCC1
# gap_des [0.31918182]
# error [1.72638]
# C=CC1CCCCCCNCC(C)C1C
# gap_des [0.6377]
# error [0.0505]
# C.CCOCCCOCON(CC)CC
# gap_des [0.93750909]
# error [0.23661]
# O=C1CCNC=C1CS
# gap_des [0.06919091]
# error [4.72485]
# Currently valid SMILES (No chemical_beauty and sanitize off): 48
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 48
# Currently valid SMILES Sanitized: 22
# Currently valid Unique SMILES Sanitized: 22
# Currently satisfying SMILES: 3
# Currently unique satisfying generation: 3
# ====
#
# time for current epoch:  218.02697491645813
# ====
# Current epoch: 16/150
# D Loss Real: 0.43167725781311733
# D Loss Fake: 0.12961300325710418
# D Loss: 0.28064513053511075
# G Loss: 1.2773398887995937
# R Loss: 0.00166921090370647
# ====
#
# CC1NC=CCCCNC1CC=O
# gap_des [0.18219091]
# error [1.85145]
# CCCCC(O)[N]CN(CC(=N)N)C(=O)O
# gap_des [0.49258182]
# error [0.05697]
# CCNONC1=NCC(NN)=C1C#N
# gap_des [0.37320909]
# error [0.23366]
# COCC1CCCC#SC1CCCC#[SH]
# gap_des [0.01561818]
# error [29.30943]
# CCCC1NCC1CCNN
# gap_des [0.05542727]
# error [11.51941]
# CC(=O)OCC1=CCC(N)C=CC1=C1C=C1
# gap_des [0.11851818]
# error [1.91585]
# CCC1CCC2C(CCOC=CC=NC2C)CS1
# gap_des [0.94054545]
# error [0.32849]
# CCCC(=CCNC)SC
# gap_des [0.55934545]
# error [0.00082]
# CNNC(=O)ONCCNC1C=CC=CC=N1
# gap_des [0.16851818]
# error [2.04175]
# CSC1=NC=C(CCO)C1CCCO
# gap_des [0.38909091]
# error [0.38376]
# CCC(=N)C(N)CCNN
# gap_des [0.56854545]
# error [0.01503]
# CCC(C)CCON1C=CCSC=C1
# gap_des [0.76274545]
# error [0.40422]
# CCCc1ccoc1CCC
# gap_des [0.72529091]
# error [0.22243]
# CCC1CCCC(CCC=O)COCNC1
# gap_des [0.93994545]
# error [0.38101]
# CCCC1CCC2CC(C1)CN1NCCC21
# gap_des [0.74877273]
# error [0.08016]
# Currently valid SMILES (No chemical_beauty and sanitize off): 42
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 42
# Currently valid SMILES Sanitized: 15
# Currently valid Unique SMILES Sanitized: 15
# Currently satisfying SMILES: 7
# Currently unique satisfying generation: 7
# ====
#
# time for current epoch:  223.24268317222595
# ====
# Current epoch: 17/150
# D Loss Real: 0.4413965462486525
# D Loss Fake: 0.14082865228039632
# D Loss: 0.29111259926452443
# G Loss: 1.2848777966798792
# R Loss: 0.0016628066083452335
# ====
#
# CCC(CCCONCC(C)OC)OC
# gap_des [0.35980909]
# error [1.0582]
# C=C1CCC(C=CC(C)C(=O)[C]N)N1N
# gap_des [0.25629091]
# error [0.40696]
# CC1CC1CC(N)C(N)OCN=O
# gap_des [0.41867273]
# error [0.58336]
# NCCCCCCc1ccccc1SCC#[SH]
# gap_des [0.0072]
# error [64.50603]
# COCOCNC1=CC=C(C)C(CO)N1
# gap_des [0.43411818]
# error [0.30675]
# CC(C)C1CC(=N)C(C2CC2C)=C1NS
# gap_des [0.54338182]
# error [0.20376]
# CCOCCC(O)ONO
# gap_des [0.36001818]
# error [1.05653]
# C=CC1CC=CSC(=N)CCC1
# gap_des [0.12537273]
# error [2.52234]
# CN1CCC1
# gap_des [0.48836364]
# error [0.5468]
# CCSC1CCCCC2CCCCCC21
# gap_des [0.30089091]
# error [1.26304]
# NC1CCCCCCCCC1=O
# gap_des [0.36172727]
# error [0.78249]
# CC1=CC=CN=CC=CNCNC1=C[C]1N=C2NCC12
# gap_des [0.04521818]
# error [6.0582]
# C=CSSCCNCC(C)O
# gap_des [0.62783636]
# error [0.17128]
# CSCCC(C)OCCSCCS
# gap_des [0.81495455]
# error [0.3314]
# N#CCNCC1CC=NCCCCN1
# gap_des [0.90397273]
# error [0.31406]
# CC1C2CCCC(=O)CC1CCC2
# gap_des [0.98090909]
# error [0.31569]
# CCCC(C)NCCCSO
# gap_des [0.33421818]
# error [1.0096]
# COC1CCN(S)C(C)=CC(=N)C2=C1CC2
# gap_des [0.39331818]
# error [0.14209]
# Currently valid SMILES (No chemical_beauty and sanitize off): 51
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 51
# Currently valid SMILES Sanitized: 18
# Currently valid Unique SMILES Sanitized: 18
# Currently satisfying SMILES: 3
# Currently unique satisfying generation: 3
# ====
#
# time for current epoch:  221.59155225753784
# ====
# Current epoch: 18/150
# D Loss Real: 0.43410401809330723
# D Loss Fake: 0.13780946205347633
# D Loss: 0.2859567400733918
# G Loss: 1.288578957175287
# R Loss: 0.001661779353921504
# ====
#
# C=CCCOOCCC(C)C[C](C=C)CC
# gap_des [0.70573636]
# error [0.31565]
# CSC1=CC=CSCCSC(CN)=C1
# gap_des [0.97436364]
# error [0.53444]
# CCOC1(C)CCCC(CCO)C1CC
# gap_des [0.42531818]
# error [0.94258]
# C=CC1NN1CCC1CCN(CCCO)C1(O)CC
# gap_des [0.66539091]
# error [0.02178]
# C=C(C)C#CN=C1OCCC1CCCCNC
# gap_des [0.44624545]
# error [0.08459]
# CCCC1C=CC=CC=C1CO
# gap_des [0.33298182]
# error [0.64202]
# CCCC1C#CC1(C)CCCCCC1CCCCC1C=O
# gap_des [0.33579091]
# error [0.81793]
# C=C=NCCCOC(CCOCC)NCC(=O)OOOC
# gap_des [0.12336364]
# error [4.01435]
# CSC(SCCSC#[SH])N1CC1C
# gap_des [0.42374545]
# error [0.28603]
# C=CCCCCCC1CC(C)C(O)CC1CCC
# gap_des [0.46239091]
# error [0.5287]
# CCOOCC(CSNC)OC
# gap_des [0.15809091]
# error [2.89261]
# C=C1CCCCCCC2CC2NCC1O
# gap_des [0.76358182]
# error [0.17942]
# CNN=CC(N)CCOC(C)=O
# gap_des [0.82245455]
# error [0.32139]
# C[C]1CCCC2=CC=CCC12
# gap_des [0.79170909]
# error [0.45905]
# CCC(OCOO)C(C)C1(C2CC2OCOC)CC1
# gap_des [0.03514545]
# error [19.68881]
# C=CC1C=NOC12C=CC=CC=CC1=CC2=CC=CC=C1
# gap_des [0.14228182]
# error [1.68863]
# Currently valid SMILES (No chemical_beauty and sanitize off): 39
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 39
# Currently valid SMILES Sanitized: 16
# Currently valid Unique SMILES Sanitized: 16
# Currently satisfying SMILES: 5
# Currently unique satisfying generation: 5
# ====
#
# time for current epoch:  266.3332669734955
# ====
# Current epoch: 19/150
# D Loss Real: 0.4334459828869732
# D Loss Fake: 0.13964176084396343
# D Loss: 0.2865438718654683
# G Loss: 1.2634412564229274
# R Loss: 0.0016527714428226441
# ====
#
# C=C(CCCN)CSC
# gap_des [0.6754]
# error [0.19959]
# COCCC1CCCCC1CC1S[N]S1
# gap_des [0.46021818]
# error [0.12985]
# CCOC(C#N)C=CC(C)NNSC=N
# gap_des [0.6098]
# error [0.11662]
# C.CCCCNC1CNC(=NC(C)C)CN1
# gap_des [0.47794545]
# error [0.16358]
# CCCCCCC=CCC1=CC(S)(C(=O)O)S1
# gap_des [0.37910909]
# error [0.39558]
# C=NSC=CC(C)C(CC)OC
# gap_des [0.12639091]
# error [1.9766]
# CNCC1=CC=CC=CNCCNC[C]1CCNN
# gap_des [0.84209091]
# error [0.46455]
# COC(=N)Nc1ccccc1CC12CCNCC1CC2
# gap_des [0.96924545]
# error [0.55527]
# CN=C1CSNNCN1
# gap_des [0.29884545]
# error [0.91656]
# C#CC(CO)CC(=O)CCCCCNS
# gap_des [0.44769091]
# error [0.06904]
# COC(CO)CC1CC(C)P1
# gap_des [0.42692727]
# error [0.89839]
# COCC=CC(C)C1CSCCS1
# gap_des [0.85662727]
# error [0.34802]
# CSP(O)CCCCCOCOO
# gap_des [0.0745]
# error [7.21954]
# COC(=N)OCC1[C]CSC1
# gap_des [0.90421818]
# error [0.47747]
# NNCC(O)CCNOCCO
# gap_des [0.45040909]
# error [0.58776]
# CC=CCN1CC(S)NCC=CC1CCC
# gap_des [0.19858182]
# error [1.57282]
# CCCC(CC)N1C(C)=CC12CC2N(C)C
# gap_des [0.37481818]
# error [0.37062]
# C=CCCCCC
# gap_des [0.65968182]
# error [0.14815]
# C=C1COCC(NC=C2CC2C)C1
# gap_des [0.03827273]
# error [11.46755]
# C=CC(C)COCCC1CC1CCC
# gap_des [0.57928182]
# error [0.12552]
# NCCCCCCCCCCCC=CC=CO
# gap_des [0.88199091]
# error [0.43514]
# CC1CCCCOCC(C)C1OOCCC1CCCCCC1
# gap_des [0.24075455]
# error [2.0169]
# O=CCOCOC(CCO)CCCO
# gap_des [0.35726364]
# error [0.97238]
# Currently valid SMILES (No chemical_beauty and sanitize off): 47
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 47
# Currently valid SMILES Sanitized: 23
# Currently valid Unique SMILES Sanitized: 23
# Currently satisfying SMILES: 7
# Currently unique satisfying generation: 7
# ====
#
# time for current epoch:  301.90142917633057
# ====
# Current epoch: 20/150
# D Loss Real: 0.43511890616393895
# D Loss Fake: 0.1402050552772727
# D Loss: 0.28766198072060584
# G Loss: 1.2319425841172535
# R Loss: 0.0016635349872387083
# ====
#
# O=c1ccccc2c1CNC=NC=CC=C2
# gap_des [0.718]
# error [0.45247]
# CCC(O)CC=CN
# gap_des [0.94566364]
# error [0.4403]
# CC(S)CSCN=O
# gap_des [0.41709091]
# error [0.38617]
# CCCC1=CNCC(C)C1=O
# gap_des [0.95732727]
# error [0.47714]
# CCCC(NCC(N)CC)OC1(O)C=C1N=COO
# gap_des [0.92389091]
# error [0.39229]
# COCCN(C=O)N=C(O)OO
# gap_des [0.34679091]
# error [0.76973]
# COC(C)OC1CCCCCN(C)CCC1
# gap_des [0.68795455]
# error [6.e-05]
# O=Cc1ccncc2scnnccc1-2
# gap_des [0.71980909]
# error [0.55522]
# CCC1=CNCC(C)C1N
# gap_des [0.29566364]
# error [0.94969]
# CCCCCC1=C(C)CCCC(NOC)O1
# gap_des [0.64566364]
# error [0.03689]
# CCC(CC)C(C)C(C)(C)CC(O)=C(C)OO
# gap_des [0.89997273]
# error [0.21127]
# N=C1C([O])=NC=CCCSC1N
# gap_des [0.70653636]
# error [0.44009]
# CCS(=S)C[SH](CSSCO)SS
# gap_des [0.17251818]
# error [1.04196]
# CC(C)n1ccc2c1CC=COC(=O)C=CC=C2
# gap_des [0.52074545]
# error [0.30734]
# CCCCCOCCCCCC1(CC)C=CC=C1
# gap_des [0.23035455]
# error [1.85067]
# C=CC1=CCCCCC(S)=NC1
# gap_des [0.02294545]
# error [18.51416]
# Cc1c(OCOCC2CO2)c1=O
# gap_des [0.52476364]
# error [0.17258]
# CSCCCCCOC1=CC=CCCC=N1
# gap_des [0.51769091]
# error [0.03736]
# CNC(C#CCO)CCC=NN
# gap_des [0.93177273]
# error [0.46558]
# CCOCC(=O)CCCCCN
# gap_des [0.21304545]
# error [1.89927]
# C=C(COCC)OSCNSC
# gap_des [0.63690909]
# error [0.23099]
# Currently valid SMILES (No chemical_beauty and sanitize off): 45
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 45
# Currently valid SMILES Sanitized: 21
# Currently valid Unique SMILES Sanitized: 21
# Currently satisfying SMILES: 4
# Currently unique satisfying generation: 4
# ====
#
# time for current epoch:  221.56241035461426
# ====
# Current epoch: 21/150
# D Loss Real: 0.43271110476790997
# D Loss Fake: 0.14285098718128342
# D Loss: 0.2877810459745967
# G Loss: 1.21530931065048
# R Loss: 0.0016560150728817434
# ====
#
# CCCC1=CC=NC2=CN=C2CC1C
# gap_des [0.88073636]
# error [0.46036]
# COC(C)C(C)P(C)SS[C]O
# gap_des [0.43665455]
# error [0.10381]
# CCC1OS[C](O)CCSC1C
# gap_des [0.16439091]
# error [2.12411]
# CCCCC1(CC)CNNC1
# gap_des [0.95120909]
# error [0.27535]
# C=CCN(O)C(C)=O
# gap_des [0.71155455]
# error [0.16043]
# CC(O)COC(O)C1CCC(C)C1
# gap_des [0.94323636]
# error [0.16626]
# CCOCCNCCN.CO
# gap_des [0.64437273]
# error [0.1252]
# O=C(C=S)On1cnccocn1
# gap_des [0.67821818]
# error [0.53237]
# CC(C)CNNNC(C=NNCO)C1(N)CC1O
# gap_des [0.10640909]
# error [4.19236]
# CC(C)C#CCC1CC1(C)CF
# gap_des [0.161]
# error [2.36657]
# CCC1OC=CSC1n1cc[nH]nccn1
# gap_des [0.58180909]
# error [0.10132]
# CCCC(=O)C1(C)PS1
# gap_des [0.93778182]
# error [0.47236]
# CCCCCCC1=C2[C]C(=C1)C=C2CC
# gap_des [0.08245455]
# error [4.2602]
# C=C(CCCCC=CC)OCC
# gap_des [0.84013636]
# error [0.38613]
# Currently valid SMILES (No chemical_beauty and sanitize off): 38
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 38
# Currently valid SMILES Sanitized: 14
# Currently valid Unique SMILES Sanitized: 14
# Currently satisfying SMILES: 2
# Currently unique satisfying generation: 2
# ====
#
# time for current epoch:  222.30290412902832
# ====
# Current epoch: 22/150
# D Loss Real: 0.4301409346325962
# D Loss Fake: 0.13770729258368555
# D Loss: 0.28392411360814085
# G Loss: 1.2007570972189234
# R Loss: 0.0016511109019832118
# ====
#
# CN1CC(CO)C(O)C1CNO
# gap_des [0.62321818]
# error [0.07189]
# C=CCC(CO)COCCNCCOCC(C)C
# gap_des [0.56844545]
# error [0.17057]
# C#CCCCCC1=C(CNC)CCCC1
# gap_des [0.95479091]
# error [0.36511]
# CNCC(O)NC1COC=N1
# gap_des [0.86007273]
# error [0.24411]
# C=CC1=CCC=CC(CC(=N)N)C1
# gap_des [0.74051818]
# error [0.39751]
# CNCCCC1=C2[N]C(C)=CC=CC=CN=C2N1
# gap_des [0.97598182]
# error [0.71543]
# COC(SC)SC(O)CO
# gap_des [0.28612727]
# error [1.32239]
# Nc1ccc2cc(NCOO)nnc2c1
# gap_des [0.22128182]
# error [0.71148]
# COC(C=CCCCC1CC(C)C(N)C1)COO
# gap_des [0.18885455]
# error [2.4947]
# C=CCCOCC(C(=O)COC)C(CO)CCC
# gap_des [0.60071818]
# error [0.02724]
# C=C(CC)CC(CCC=CCCCCO)C(=C)CC
# gap_des [0.85063636]
# error [0.39463]
# C=CCC(C)C(CC)CCCC(C)CC
# gap_des [0.24287273]
# error [1.62246]
# CCCC1CCCC=C(C)C1CCCC(C)CC
# gap_des [0.66144545]
# error [0.12801]
# NC(O)(N=C(O)CCCNO)SS
# gap_des [0.95098182]
# error [0.48877]
# CC(COCC(=O)CO)=C(O)O
# gap_des [0.79437273]
# error [0.2818]
# CCCCCCCC=CCC1CCC1CN
# gap_des [0.7235]
# error [0.20171]
# C=CC(=O)OC(C)C1CC1
# gap_des [0.84983636]
# error [0.4257]
# CCCCC(C)OC(NC)C(CC)C(C)C
# gap_des [0.9286]
# error [0.20784]
# CCCC1CCCP(C(CN)CN)O1
# gap_des [0.66441818]
# error [0.08757]
# Currently valid SMILES (No chemical_beauty and sanitize off): 47
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 47
# Currently valid SMILES Sanitized: 19
# Currently valid Unique SMILES Sanitized: 19
# Currently satisfying SMILES: 6
# Currently unique satisfying generation: 6
# ====
#
# time for current epoch:  224.18787002563477
# ====
# Current epoch: 23/150
# D Loss Real: 0.4281586470523318
# D Loss Fake: 0.1381788923976502
# D Loss: 0.283168769724991
# G Loss: 1.19891955440747
# R Loss: 0.001655470107452593
# ====
#
# CCC1(CO)CC=C1C=NC
# gap_des [0.69880909]
# error [0.24709]
# CC1CNC2CNCCC(=O)C3(CCC3)C1CO2
# gap_des [0.62277273]
# error [0.0549]
# CC1CC2CNCC1CN2C
# gap_des [0.61726364]
# error [0.01668]
# CCCCOC(CN)C1=C(N)CC1
# gap_des [0.19445455]
# error [1.84042]
# CCC(O)CCNC1C(C)C1C(CO)C(O)CO
# gap_des [0.72489091]
# error [0.01808]
# C=C(CC1OOCOC1CC)OC
# gap_des [0.11252727]
# error [4.57724]
# CSC(SS)C(N)CS[N]COS
# gap_des [0.71287273]
# error [0.49191]
# C=C(CO)OCC
# gap_des [0.95825455]
# error [0.43054]
# CCC1(C#N)C(C)C(CO)C(C)C1N
# gap_des [0.41895455]
# error [0.47898]
# C=NCCCCC(C)OC1CCCC1
# gap_des [0.48218182]
# error [0.27129]
# CCC(CCNCNOOCC=CO)OC
# gap_des [0.53125455]
# error [0.17698]
# C=C1CCC=C2C=CC=CC=CCC2CC1COO
# gap_des [0.02134545]
# error [17.54606]
# COC1CCCCCCCN(C)C=C1O
# gap_des [0.37363636]
# error [0.50709]
# CCCCOOCCCC(C)C1CCCC2CC2C1
# gap_des [0.87731818]
# error [0.24719]
# CC(=N)NC1(C)OC2CCCCCCC21
# gap_des [0.99161818]
# error [0.37757]
# NN1CCC=CCCNNCC=CCC1
# gap_des [0.40808182]
# error [0.11066]
# CCCC1CCCCCCC(=N)C2=C(O)C2COC1
# gap_des [0.48024545]
# error [0.05733]
# CCCOCC=CC(=C(C)OC)C(CC)CC
# gap_des [0.35964545]
# error [0.57295]
# CCC(C)[PH](C)(F)C1CCC1
# gap_des [0.95433636]
# error [0.3421]
# Currently valid SMILES (No chemical_beauty and sanitize off): 54
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 54
# Currently valid SMILES Sanitized: 19
# Currently valid Unique SMILES Sanitized: 19
# Currently satisfying SMILES: 7
# Currently unique satisfying generation: 7
# ====
#
# time for current epoch:  220.061368227005
# ====
# Current epoch: 24/150
# D Loss Real: 0.4344379996907884
# D Loss Fake: 0.14375776662558748
# D Loss: 0.28909788315818796
# G Loss: 1.1812615704133316
# R Loss: 0.0016519120851630606
# ====
#
# CC(=O)C1NC2C=CCNOC1CNCOC2
# gap_des [0.55641818]
# error [0.09925]
# C=C1CCCCC2(CCCC2O)C1
# gap_des [0.45956364]
# error [0.3229]
# CC(C)CCC1NNCN=NC=C(N)N1
# gap_des [0.55784545]
# error [0.00397]
# CC(=O)C1SC1(C=CO)CO
# gap_des [0.39346364]
# error [0.35934]
# CC1CCCCCOC2CCCOCC1C(C)OC2
# gap_des [0.65658182]
# error [0.136]
# COCCCC1CCC2(OCOC)CC12
# gap_des [0.46812727]
# error [0.55766]
# COCC(CO)CCC(C)CCCO
# gap_des [0.81276364]
# error [0.04042]
# C=C1C(=NC)NCCCC(C)C1C
# gap_des [0.49149091]
# error [0.02489]
# C=CC=C1C(CC)CC1NCC
# gap_des [0.5471]
# error [0.15549]
# CN1CNOSCNC1C(N)CO
# gap_des [0.99260909]
# error [0.35577]
# CCCC1=CC=C(C)CC=CC=CC=C(CC)CC(=O)OC1
# gap_des [0.79873636]
# error [0.26628]
# C=CC(Cl)CC1=CC=C(O)C1S
# gap_des [0.33749091]
# error [0.38544]
# CCCC(CO)CC1(C)OC1COC
# gap_des [0.72607273]
# error [0.05194]
# CC(C)=CCC(O)=CS
# gap_des [0.13081818]
# error [3.0533]
# CCC(C)CCCC(CC)OO
# gap_des [0.63499091]
# error [0.18736]
# CCc1ccc(CO)cc1CN1CC(C)C1
# gap_des [0.77522727]
# error [0.3999]
# C=CN=CCN=NNN=C=NC(C)(C)CCCO
# gap_des [0.26346364]
# error [0.07397]
# CCOC(C)CC1=NC(O)=C(N(C)CC)C1
# gap_des [0.24752727]
# error [1.53295]
# CC1SCC1C1=CCC1C1CO1
# gap_des [0.31820909]
# error [0.56429]
# Currently valid SMILES (No chemical_beauty and sanitize off): 51
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 51
# Currently valid SMILES Sanitized: 19
# Currently valid Unique SMILES Sanitized: 19
# Currently satisfying SMILES: 7
# Currently unique satisfying generation: 7
# ====
#
# time for current epoch:  224.42897391319275
# ====
# Current epoch: 25/150
# D Loss Real: 0.4330595380442154
# D Loss Fake: 0.1444174516496163
# D Loss: 0.2887384948469158
# G Loss: 1.172825333000957
# R Loss: 0.0016455300512795612
# ====
#
# C=CC=CCCCCCCC(O)C=CC
# gap_des [0.62200909]
# error [0.14573]
# CC(O)NCCNC1CNNOCCC(C)C1C
# gap_des [0.9274]
# error [0.27274]
# O=c1ccc2ccc1cccoc2C1=CC=C1
# gap_des [0.48346364]
# error [0.42571]
# CC(CCCCCCCNN)CCCC1N[PH]1=O
# gap_des [0.76139091]
# error [0.22748]
# COC(=O)C1CC(C)COCC=CCCCS1
# gap_des [0.8848]
# error [0.34737]
# CCC1C=CC=CC=C(O)C(C)=CC=CCCO1
# gap_des [0.6286]
# error [0.21016]
# O=C1NC1=C(C=CO)C1COCCO1
# gap_des [0.97513636]
# error [0.67708]
# O=C1CCCCC(=O)CCCC1
# gap_des [0.77522727]
# error [0.36927]
# O=C1CCCNNC(C2CCCCC2)=CS1
# gap_des [0.17747273]
# error [1.55198]
# CC1CC2C3CC(=O)NC4CC1C432
# gap_des [0.70441818]
# error [0.2635]
# CC(CC1C=CC1)CC(C)(N)O
# gap_des [0.3829]
# error [0.83645]
# CCC(CC)CC1C=CC=C(C)C=C1
# gap_des [0.80404545]
# error [0.27849]
# CC1CCC2CC(=O)COC(C1)C2
# gap_des [0.769]
# error [0.23334]
# CNC1CCCCC(C(C)CC(N)N=O)CNOC1
# gap_des [0.68668182]
# error [0.23991]
# CCCCCCC(C)CCCSSCCCC
# ...
# gap_des [0.92276364]
# error [0.14336]
# CCCCCOCCC1CC1C(O)C(N)CCCO
# gap_des [0.58569091]
# error [0.19986]
# CC1CC(C)(C(C)CCO)C1
# gap_des [0.69672727]
# error [0.15753]
# CC(C)CCCCCC1CCC1C
# gap_des [0.60336364]
# error [0.49065]
# C#CC1=CC=C1CCCNSC
# gap_des [0.47407273]
# error [0.05911]
# CCC12CCC(C3CC3)C1CC(C)(C(C)C)C2
# gap_des [0.74129091]
# error [0.05023]
# C=CCSC1CCCC(C)CS1
# gap_des [0.54729091]
# error [0.03939]
# CC.CCCNCC(N)CCC
# gap_des [0.70174545]
# error [0.01192]
# CCC(CC)CCCC=CC1CCCCCC1
# gap_des [0.80800909]
# error [0.16206]
# CC1C=C=C1CCCCCCC1=C=C=C1
# gap_des [0.13037273]
# error [1.77649]
# CCCCC=C1CCCCCCCCCCC1
# gap_des [0.83229091]
# error [0.24507]
# CC=CCNCC=O
# gap_des [0.4232]
# error [0.24008]
# C=CC(C)CCCCCCCCC
# gap_des [0.83502727]
# error [0.17939]
# O=C1C=C(CSS)NC1CCS
# gap_des [0.60361818]
# error [0.46883]
# C#CC1(C)CCCC(CC)OC1
# gap_des [0.75293636]
# error [0.04521]
# CC[C](C)[C]COC(C)(N)CCO
# gap_des [0.65488182]
# error [0.08168]
# COC1(C)C=NC2=NC=CC=CC=CC2O1
# gap_des [0.53258182]
# error [0.12577]
# COCCCCCOCC(O)CCCCO
# gap_des [0.99614545]
# error [0.2353]
# C=C1NC1COCCCC1CCCCCC1
# gap_des [0.65948182]
# error [0.01687]
# COCCONCC1CC(C)CCCCO1
# gap_des [0.58078182]
# error [0.35199]
# O=C1C2=CC=CC=CC=CC=CC=CC3=CC=CC132
# gap_des [0.02095455]
# error [14.44439]
# C=CCC=C1C(=O)CC2CN12
# gap_des [0.59686364]
# error [0.27583]
# C=C(O)C1CCCCCC(C)CC1
# gap_des [0.85183636]
# error [0.314]
# CCCCCC(C)(CCC)OC
# gap_des [0.96966364]
# error [0.17752]
# CCCCCCCCCCN1CCCN(C)C1OC
# gap_des [0.67698182]
# error [0.05528]
# OCC1CC=C2C=NN=CC=CN[C]21
# gap_des [0.12424545]
# error [1.54922]
# CC(C)CC1=NC(CS)=C1CCN
# gap_des [0.50713636]
# error [0.02634]
# C=C(CC)NCC(CC=N)CCCCC
# gap_des [0.68893636]
# error [0.14936]
# CCN=CC=CCSC1=CC1CC
# gap_des [0.31088182]
# error [0.44044]
# CN1C=C1C1CCCCC1=O
# gap_des [0.44643636]
# error [0.04134]
# CNSC(=O)OSCC(C)CO
# gap_des [0.18032727]
# error [1.99997]
# CCCCN1CCCOC(O)C1
# gap_des [0.71468182]
# error [0.10733]
# CCCCN(OCO)C(N)N
# gap_des [0.20148182]
# error [2.7568]
# CC1C=CCCCC(C)CC1
# gap_des [0.93049091]
# error [0.27567]
# C=C(C)CCC(C)(C)C(C)CC
# gap_des [0.87962727]
# error [0.25818]
# CCCCCCCCCCC1CCCCO1
# gap_des [0.99094545]
# error [0.15787]
# CCCCCCCCC1C=C1CCC
# gap_des [0.71849091]
# error [0.07613]
# C=CC(CC(C)C)C1NNCC2NC(CCC)C2N1
# gap_des [0.45496364]
# error [0.04654]
# COCONC1C=C(CO)C(N)(C=O)NCC1
# gap_des [0.18349091]
# error [1.97674]
# CCCCCC(C)CCOCCCC
# gap_des [0.71723636]
# error [0.17034]
# Currently valid SMILES (No chemical_beauty and sanitize off): 63
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 63
# Currently valid SMILES Sanitized: 40
# Currently valid Unique SMILES Sanitized: 40
# Currently satisfying SMILES: 22
# Currently unique satisfying generation: 22
# ====
#
# time for current epoch:  223.46306538581848
# ====
# Current epoch: 146/150
# D Loss Real: 0.5437795167095996
# D Loss Fake: 0.2396245964753311
# D Loss: 0.3917020565924653
# G Loss: 0.5237411262044585
# R Loss: 0.0014924648007521954
# ====
#
# CC1CCCCNC2=CCCCCC21
# gap_des [0.85410909]
# error [0.30382]
# CCC(C)COCCCC(C)CO
# gap_des [0.8609]
# error [0.07709]
# CCCCCC1CCOC(C)C1CCC
# gap_des [0.81971818]
# error [0.04062]
# CC#CCCCNCCC(CC)CCCCCC
# gap_des [0.82328182]
# error [0.21978]
# CCCC(CCC)CC(CC)CC
# gap_des [0.93995455]
# error [0.25207]
# CC#CCCCCC(CCCCCCCCC)CCC(C)C
# gap_des [0.92697273]
# error [0.0947]
# C=CC1CC(=S)C(C)C1
# gap_des [0.54130909]
# error [0.06841]
# CCSCCCC1CSC(CC)C(C)O1
# gap_des [0.4323]
# error [0.53459]
# CCOCC(C)C=C1C=C(S)N=CC=CCS1
# gap_des [0.34072727]
# error [0.12083]
# CC=C1CC(C)NNC(N)C1C
# gap_des [0.53421818]
# error [0.13505]
# CCC(C)CCCCCC(C)C
# gap_des [0.95006364]
# error [0.31823]
# CCC1=NC=C(C=O)N=C(N)S1
# gap_des [0.02486364]
# error [13.4736]
# O=C1C=CC=Cn2ccc1cccs2
# gap_des [0.48885455]
# error [0.43771]
# C=CCCCCC(C)CCCCCCC
# gap_des [0.8144]
# error [0.25399]
# CCC(C#N)OCCCCCC(C)C
# gap_des [0.71264545]
# error [0.09761]
# COCCCC1CCCCC1OC
# gap_des [0.81860909]
# error [0.06548]
# OC1=C2NNCCC=CNC2=C1
# gap_des [0.28038182]
# error [0.43346]
# C=CCOC1OC(CCCCC=O)C1C
# gap_des [0.68024545]
# error [0.01722]
# CCCC(C)=CCSNOC
# gap_des [0.87451818]
# error [0.30131]
# CCOCCCOOCC(C)(CC)CC
# gap_des [0.94673636]
# error [0.34336]
# NC1OSCON1CC1CC1=O
# gap_des [0.6843]
# error [0.1522]
# CCCCCSCCCCCCNCCCC
# gap_des [0.64792727]
# error [0.0759]
# OCC1SC2SCSNN=C12
# gap_des [0.51076364]
# error [0.17827]
# CCCCCCCCC(CC)C(C)CO
# gap_des [0.75765455]
# error [0.09442]
# CCCC(N)OOC(C)CCOO
# gap_des [0.7752]
# error [0.14275]
# OCCC1=CC1CC1CCN1CO
# gap_des [0.49217273]
# error [0.16462]
# CCC(CCO)CCCCN(C)C
# gap_des [0.92438182]
# error [0.23637]
# CCC(N)CCCCCNN1C=CC(C)NCCN1
# gap_des [0.73609091]
# error [0.23078]
# CCC1CCC(C)CC(O)O1
# gap_des [0.95032727]
# error [0.15269]
# CC1CCCOCCCC1CN1CC1(O)CCCO
# gap_des [0.89955455]
# error [0.1901]
# CCCCCC(CCC(C)O)COC
# gap_des [0.82430909]
# error [0.05358]
# Currently valid SMILES (No chemical_beauty and sanitize off): 45
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 45
# Currently valid SMILES Sanitized: 31
# Currently valid Unique SMILES Sanitized: 31
# Currently satisfying SMILES: 22
# Currently unique satisfying generation: 22
# ====
#
# time for current epoch:  221.5570433139801
# ====
# Current epoch: 147/150
# D Loss Real: 0.5439169406171006
# D Loss Fake: 0.24016944621352182
# D Loss: 0.39204319341531124
# G Loss: 0.5255195525101417
# R Loss: 0.0014904780402793076
# ====
#
# CC1=CC=CC=CCCCCCCCCC1
# gap_des [0.74266364]
# error [0.1976]
# CCCP(C=CC=C(C)CC)CON
# gap_des [0.82960909]
# error [0.42364]
# CCCC(CCCO)C(CCC)CCOC
# gap_des [0.87895455]
# error [0.07104]
# COCCCCC(C)CSC(O)O
# gap_des [0.77415455]
# error [0.13367]
# CCC1CCCCCCOC(C)CCCC1
# gap_des [0.72284545]
# error [0.13861]
# CCCCCCC1CCC(C)C1N
# gap_des [0.8987]
# error [0.28902]
# COC1CCC2C=CCCCCCCC2O1
# gap_des [0.4197]
# error [0.6348]
# CCCC1CCCCCCC1OC
# gap_des [0.75208182]
# error [0.05241]
# CCC1CCC(C)CC(CC(O)CCCO)C1CC
# gap_des [0.80716364]
# error [0.0068]
# C=C(NCCCC(O)COC)C(O)OOO
# gap_des [0.53081818]
# error [0.20775]
# C=C1COCCCC(CCCCCO)OC1
# gap_des [0.9333]
# error [0.28303]
# CCCOCCCCCCC1CC(C)C1C
# gap_des [0.78375455]
# error [0.04316]
# CCC[N]C(CCCO)OC
# gap_des [0.40115455]
# error [0.58977]
# CC=C(OCC)C(O)CCOO
# gap_des [0.64571818]
# error [0.13806]
# CCCCPC(CC)C(CC)CCO
# gap_des [0.72206364]
# error [0.04454]
# CCCCC1CCCCCCCC1C
# gap_des [0.57905455]
# error [0.52476]
# CCC1CCC1CCC1CCCCC1
# gap_des [0.99195455]
# error [0.13425]
# C=C(C)C1C(=O)OC1CO
# gap_des [0.85847273]
# error [0.38334]
# CCCCC(CC)CCCOC(CCO)CCCC
# gap_des [0.85265455]
# error [0.07005]
# CCOCC(O)(CCO)POS[SH](O)CS
# gap_des [0.60822727]
# error [0.07448]
# O=C(OOO)C1=CCC(CO)=C1
# gap_des [0.54752727]
# error [0.03783]
# CC(C)CCCCCC(O)CCCCCCO
# gap_des [0.80779091]
# error [0.04789]
# O=C(O)CCC1C=CCC1
# gap_des [0.11533636]
# error [3.88434]
# CCNCCC1OC2CCC(C)CCNCC12
# gap_des [0.82308182]
# error [0.20502]
# CC(CNN=NCC=N)C(=O)OON
# gap_des [0.15853636]
# error [1.45241]
# CCCC(O)C(CC)(NOOC)OC
# gap_des [0.86179091]
# error [0.12793]
# COCCOC1COC1CCN
# gap_des [0.73311818]
# error [0.10844]
# C=C(O)CCCC(C)CCCCO
# gap_des [0.44688182]
# error [0.59511]
# CCCCNCCC1NC1CC(CC)CNN
# gap_des [0.81501818]
# error [0.17712]
# COCCCCCCC1CCC(C)CC1C
# gap_des [0.73786364]
# error [0.12241]
# Currently valid SMILES (No chemical_beauty and sanitize off): 54
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 54
# Currently valid SMILES Sanitized: 30
# Currently valid Unique SMILES Sanitized: 30
# Currently satisfying SMILES: 19
# Currently unique satisfying generation: 19
# ====
#
# time for current epoch:  221.1814513206482
# ====
# Current epoch: 148/150
# D Loss Real: 0.5453759151812337
# D Loss Fake: 0.24274159004182919
# D Loss: 0.39405875261153145
# G Loss: 0.5164429721049064
# R Loss: 0.0014938918206107393
# ====
#
# COCC(C)(C)CCCCC(C)C(C)OC
# gap_des [0.51408182]
# error [0.55914]
# CC=CCCCCCCCCCC1CCCC1
# gap_des [0.49992727]
# error [0.45309]
# CCNC1=CCCNC=CC(NCC2CCCCO2)=CO1
# gap_des [0.22961818]
# error [0.99137]
# CCC(O)C1OCCC1CCO
# gap_des [0.83409091]
# error [0.08176]
# COCCCC1CC2CCC1C2C
# gap_des [0.69104545]
# error [0.21546]
# CCOON1CC(C)CC12OC2CC
# gap_des [0.60048182]
# error [0.15154]
# CCCOC1CC=C(CO)C=C=CCC1
# gap_des [0.51032727]
# error [0.02106]
# CCCCCOCC(N)C1CCCC1
# gap_des [0.79846364]
# error [0.04765]
# CCC1SCCCCC1=CCCOC
# gap_des [0.68541818]
# error [0.17625]
# CC1=CC=CC2=CCCCCC12
# gap_des [0.63184545]
# error [0.18049]
# CCC(O)ONCC(C=N)=COC
# gap_des [0.31366364]
# error [0.84211]
# CC(C)CCCC1CCOCCC2CC12
# gap_des [0.82201818]
# error [0.01813]
# CCCSCC=NC1(C=O)CS1
# gap_des [0.34752727]
# error [0.24884]
# CCCCCCC1CCC1(C)CCCCC
# gap_des [0.76489091]
# error [0.15523]
# C=NCCC(CCC)CCC(C)N
# gap_des [0.50877273]
# error [0.23201]
# CC(CN)CC(C)CC(C)NNCCCCO
# gap_des [0.67054545]
# error [0.08267]
# C=CCC1COCP(CON)C(C)O1
# gap_des [0.72784545]
# error [0.02928]
# CCCC(C)OCCCCC(C)CO
# gap_des [0.92819091]
# error [0.23582]
# CCCC1C(C)CC12CCC2C
# gap_des [0.65861818]
# error [0.23189]
# CCC1CC1N=CC1OC1CO
# gap_des [0.52256364]
# error [0.26743]
# c1ccc(C2CCCCCCS2)cc1
# gap_des [0.22478182]
# error [1.41691]
# CCCCCC(CCN)CCCN(CO)OC
# gap_des [0.57916364]
# error [0.25303]
# N=CCCC1=CC=C(S)C12CCC2
# gap_des [0.32759091]
# error [0.43643]
# CCCNC(C(C)CC)C1(F)C(C)C(O)C1C
# gap_des [0.79111818]
# error [0.12007]
# CCCCC1CC(C)CCOC1=O
# gap_des [0.85793636]
# error [0.25642]
# CCNCCCCCP(O)CCC(C)C
# gap_des [0.92870909]
# error [0.24477]
# CC1CCC(C)CC(C)C1
# gap_des [0.75210909]
# error [0.17695]
# CCC1CC(CCO)CSC1N
# gap_des [0.94018182]
# error [0.29942]
# CCCCCC(O)CCCC(C)CC
# gap_des [0.8952]
# error [0.07153]
# C=C(CCCC)SCN(N)CN=O
# gap_des [0.53025455]
# error [0.19729]
# CCC(O)C(C=O)C(O)OC
# gap_des [0.76505455]
# error [0.20226]
# CCC(C)COC(C)OOC
# gap_des [0.87768182]
# error [0.16189]
# CCCCC1C(C)CCCCCCCC1CC
# gap_des [0.91963636]
# error [0.03856]
# OCCC(CC(P)COO)C(O)CO
# gap_des [0.6729]
# error [0.02284]
# CCOON(CC(C)=N)OCCCSC
# gap_des [0.87334545]
# error [0.34785]
# C=C(CC)CCCC12SC=CC1=C2CC
# gap_des [0.47486364]
# error [0.02177]
# CCCCCN(CC(C)O)OCCC
# gap_des [0.65499091]
# error [0.08229]
# CC1CC(C2CCCC2)N(NO)O1
# gap_des [0.75505455]
# error [0.00568]
# CC=CC(C)C(C)CC(O)CCO
# gap_des [0.87161818]
# error [0.21968]
# CCC(CCCCCC(C)C)OC(C)C
# gap_des [0.94391818]
# error [0.09385]
# CCC1CC(C)C(C(=O)CO)C(C)COO1
# gap_des [0.45273636]
# error [0.39646]
# OOc1ccc2ccccocccccccc1-2
# gap_des [0.10705455]
# error [2.20956]
# CCN1CCCC(C)C(OC)C1C(C)C
# gap_des [0.83170909]
# error [0.10202]
# Currently valid SMILES (No chemical_beauty and sanitize off): 71
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 71
# Currently valid SMILES Sanitized: 43
# Currently valid Unique SMILES Sanitized: 43
# Currently satisfying SMILES: 23
# Currently unique satisfying generation: 23
# ====
#
# time for current epoch:  223.81238436698914
# ====
# Current epoch: 149/150
# D Loss Real: 0.5420286800838323
# D Loss Fake: 0.23960179426135936
# D Loss: 0.3908152371725958
# G Loss: 0.5238989219429412
# R Loss: 0.001490703121992953
# ====
#
# CCCC1CCOCC1COCCCO
# gap_des [0.8581]
# error [0.17703]
# CC(O)(CCC=N)CNPC(=O)N=O
# gap_des [0.40597273]
# error [0.22343]
# CCC(C)CC(C)CC(C)C(OC)C(ON)C(C)N
# gap_des [0.89773636]
# error [0.10349]
# CC(=CCCOO)N=C(C)N
# gap_des [0.4793]
# error [0.00237]
# COC1CCCCCCCCC1=O
# gap_des [0.79029091]
# error [0.22211]
# C=CCCCC(C)C=CC(C)C1CC1
# gap_des [0.33914545]
# error [0.62328]
# CCC1CCCCCC(COC)CCC(C)(CC)C1
# gap_des [0.8926]
# error [0.07626]
# CC=C(N)CCCCCCCC
# gap_des [0.94062727]
# error [0.34547]
# CCC1CCCOC2(CCCC2)CC1
# gap_des [0.72630909]
# error [0.14115]
# CCCCCCCCOCCCC(C)CO
# gap_des [0.6152]
# error [0.26904]
# [C]CSC(O)CCCCCCCCN
# gap_des [0.54019091]
# error [0.01139]
# CCCCC(C)CCOC1(C)OCC1O
# gap_des [0.65687273]
# error [0.18137]
# CC=C(C)CCCCCCO
# gap_des [0.8912]
# error [0.23912]
# COC(CO)CCCCCC(C)CCO
# gap_des [0.84947273]
# error [0.07168]
# CCC(C)CC(COC)C1CCCNC1N
# gap_des [0.73689091]
# error [0.03832]
# [NH]C1NC=CC=CC=CN1ONCNN
# gap_des [0.3872]
# error [0.26364]
# CCCC(C)CCC1CC1C
# gap_des [0.93595455]
# error [0.04666]
# CCCC(O)CCC(COC)OC
# gap_des [0.91012727]
# error [0.16318]
# CCC(C)CCCCCCC(C)CO
# gap_des [0.95549091]
# error [0.14049]
# CC(C)CCC(C)CCOO
# gap_des [0.85771818]
# error [0.14628]
# CCCCC(CO)C(C)C(C)C
# gap_des [0.99036364]
# error [0.21578]
# OC1=C2CC1=C1C=CC=CC=CC2=NC=C1
# gap_des [0.30042727]
# error [0.14967]
# CCCCC(C)(CCC)CCCCCN
# gap_des [0.8465]
# error [0.15478]
# COCCCCCCC(OC)OCCCOC
# gap_des [0.91474545]
# error [0.17367]
# CCOC(CN)NCCCCC(C)C
# gap_des [0.9592]
# error [0.21298]
# CCC=CC(C)CCCCCCCCC
# gap_des [0.69266364]
# error [0.04939]
# C#CC1OCCC1C1CC1C
# gap_des [0.75816364]
# error [0.19134]
# COCN=CC(C)OSCC1CC1
# gap_des [0.26513636]
# error [0.66949]
# CCCCC1CCC1CCCC
# gap_des [0.79021818]
# error [0.1153]
# CCNC(=O)CCC1CC(=CC(CN)C(=O)O)O1
# gap_des [0.40045455]
# error [0.26487]
# C#CCNC1CCC2CCCC21
# gap_des [0.55812727]
# error [0.22441]
# NC1=CC=CCCC1CCCO
# gap_des [0.4949]
# error [0.35441]
# COC1=CC=CC=CSC2NNNCCN12
# gap_des [0.1687]
# error [1.99406]
# CCCCC1C=CCCCCCCSC1
# gap_des [0.52219091]
# error [0.10322]
# CC1CC2=CC(N)CCCCCC21C
# gap_des [0.81445455]
# error [0.42411]
# CCCCCCCCCCCC(C)C
# gap_des [0.65745455]
# error [0.38427]
# NC1C=CCNCCCC=CCCC1
# gap_des [0.44286364]
# error [0.1572]
# CCC(C)NCCC1CC2CC1C2=O
# gap_des [0.58585455]
# error [0.03933]
# Currently valid SMILES (No chemical_beauty and sanitize off): 67
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 67
# Currently valid SMILES Sanitized: 38
# Currently valid Unique SMILES Sanitized: 38
# Currently satisfying SMILES: 23
# Currently unique satisfying generation: 23
# ====
#
# time for current epoch:  220.94052004814148
# ====
# Current epoch: 150/150
# D Loss Real: 0.5446074815188053
# D Loss Fake: 0.24778604073728916
# D Loss: 0.39619676112804725
# G Loss: 0.5213845605435579
# R Loss: 0.0014863351223864346
# ====
#
# CC(C)COC1CC(O)CCCCO1
# gap_des [0.93111818]
# error [0.22217]
# CCCCC(CC)C(C)(C)CC
# gap_des [0.96761818]
# error [0.28284]
# CCCC1C(C)CCC1NC(O)CC
# gap_des [0.94262727]
# error [0.22481]
# CC(C)CCCC1CCCCOCCC1
# gap_des [0.8583]
# error [0.0211]
# CC1CCCCCOOCCCCOCCO1
# gap_des [0.975]
# error [0.33938]
# O=CCOCONC(=O)C=COO
# gap_des [0.43952727]
# error [0.07158]
# C=CC(C(=C)O)C(CO)OC
# gap_des [0.45882727]
# error [0.32959]
# CCC(CC)CC1CC(O)C1
# gap_des [0.8883]
# error [0.11939]
# CCCCCCCCCCCCCC
# gap_des [0.86286364]
# error [0.1364]
# C.CCCC1COC2CCCCCC1O2
# gap_des [0.70686364]
# error [0.10192]
# CCCCCCC(CCC)C(C)(C)C
# gap_des [0.95905455]
# error [0.08005]
# CONCC(CC=NN(C)C)CNSS
# gap_des [0.4266]
# error [0.2602]
# CCCC(CC(O)CCO)NCC
# gap_des [0.78896364]
# error [0.09399]
# CCC(=S)C(C)C
# gap_des [0.48723636]
# error [0.02274]
# C=CCC=C=CSC(C)CNCC=C
# gap_des [0.32905455]
# error [0.30266]
# CCC(C)(C)COC1(C)CC1
# gap_des [0.99385455]
# error [0.21651]
# CCC1CCCCCCNCCCC1
# gap_des [0.82113636]
# error [0.20729]
# COC(OC)C1CC2COC2O1
# gap_des [0.56732727]
# error [0.40014]
# CCOC1CCCC2CC(C2)C1
# gap_des [0.99539091]
# error [0.15002]
# CC(CCO)CCC1CCCC1
# gap_des [0.67753636]
# error [0.2166]
# c1cccsc2cccc-2ccc1
# gap_des [0.16587273]
# error [1.10855]
# CCCC(CCCCCCO)OCC
# gap_des [0.98130909]
# error [0.13761]
# CC1CC(CO)(C[PH](=N)CO)O1
# gap_des [0.51381818]
# error [0.25663]
# CC=CCCCC(C)(CC)CC=N
# gap_des [0.57042727]
# error [0.04433]
# N#CCCCCOC1CCCC1
# gap_des [0.6429]
# error [0.11751]
# C=CC(C)(CCCCC)OC
# gap_des [0.98454545]
# error [0.2484]
# CCCNNCP(OO)C(C)CC
# gap_des [0.67169091]
# error [0.02823]
# CCOC=C=CC1CCCC1C
# gap_des [0.6452]
# error [0.05923]
# CCCCC(CC#N)CC1CCCC1N
# gap_des [0.68109091]
# error [0.11468]
# CCC(C)C(C)CCCCOC(C)O
# gap_des [0.99428182]
# error [0.22857]
# O=CC1CC1C1CC1NNCCO
# gap_des [0.56198182]
# error [0.14861]
# CC(=O)CCC1CN1C(C)N
# gap_des [0.66747273]
# error [0.1574]
# CC1(C)CC2CC(CO1)C2CO
# gap_des [0.92312727]
# error [0.13169]
# CCCC1CCC(CC)C(O)COOC1
# gap_des [0.70524545]
# error [0.07974]
# CCN1CCCCC(COC)CCCC1
# gap_des [0.71638182]
# error [0.20267]
# CCCCOC1(OCCCON)CCC1
# gap_des [0.74640909]
# error [0.05709]
# CCCC1(CC)C(C)C1CCC1CC1O
# gap_des [0.99453636]
# error [0.24672]
# NCCC(=O)CCCN=C1CCN1
# gap_des [0.63584545]
# error [0.20137]
# CC(C)C1=CC=CC=CSNCC1C
# gap_des [0.5447]
# error [0.05822]
# CC(N)C[SH](CCS)OC(C)C
# gap_des [0.7833]
# error [0.18315]
# CC(=O)NC1CCC(C)OC1O
# gap_des [0.76381818]
# error [0.09775]
# Currently valid SMILES (No chemical_beauty and sanitize off): 61
# Currently valid SMILES Unique (No chemical_beauty and sanitize off): 61
# Currently valid SMILES Sanitized: 41
# Currently valid Unique SMILES Sanitized: 41
# Currently satisfying SMILES: 31
# Currently unique satisfying generation: 31
# ====
#
# time for current epoch:  223.25904297828674
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Done

# %%
tf.compat.v1.keras.backend.clear_session()

# %%
# reduce the number of samples
# subsampling
idx = np.random.choice(len(y_train00), int(len(y_train00) * 0.0015), replace = False)
samples = y_train00[idx]
print (samples.shape)
# Out:
# (159,)

# %%
samples
# Out:
# array([5.146   , 7.698   , 6.89    , 4.291   , 8.313   , 5.225   ,
#        7.021   , 7.203   , 7.731   , 5.597   , 6.223   , 3.306   ,
#        2.857   , 3.075   , 5.913   , 4.035   , 5.804188, 7.342   ,
#        7.309   , 4.313   , 9.138   , 7.527   , 8.046   , 5.031   ,
#        4.767   , 8.857   , 5.747045, 5.333   , 5.837   , 3.162   ,
#        4.748   , 7.761   , 3.554   , 9.861   , 3.752   , 4.661   ,
#        3.567   , 3.606   , 5.353   , 5.772   , 4.514   , 3.203   ,
#        3.113   , 7.951   , 8.06    , 4.659   , 4.87628 , 8.191   ,
#        7.513   , 5.66541 , 6.855   , 3.211   , 5.742   , 7.976   ,
#        2.34    , 9.385   , 8.743   , 1.703   , 9.592   , 3.785   ,
#        4.601   , 9.149   , 5.927   , 5.357922, 3.135   , 5.246   ,
#        5.625   , 9.225   , 4.452   , 2.816   , 4.787   , 2.991   ,
#        8.098   , 5.989226, 4.482   , 3.644   , 6.362   , 3.573   ,
#        3.619   , 4.299   , 4.680358, 6.942   , 3.339   , 8.909   ,
#        6.762   , 6.158   , 8.806   , 9.647   , 4.83    , 5.279   ,
#        7.214   , 4.523   , 5.755208, 4.389   , 4.86    , 3.154   ,
#        6.833   , 3.521   , 4.901   , 4.629   , 8.106   , 5.812352,
#        4.751   , 2.599   , 7.617   , 6.212   , 6.071   , 6.953   ,
#        3.157   , 8.049   , 3.034   , 7.072   , 4.489879, 7.698   ,
#        4.898049, 9.44    , 5.701   , 8.515   , 6.06    , 8.931   ,
#        5.300778, 7.121   , 5.42595 , 5.368806, 5.616   , 5.366   ,
#        5.543   , 8.147   , 5.08    , 6.065   , 5.233   , 9.113   ,
#        5.706   , 7.516   , 3.197   , 6.909   , 5.110298, 4.634   ,
#        3.004   , 5.608   , 3.102   , 5.747   , 4.041   , 3.195   ,
#        5.478   , 3.992   , 8.376   , 4.142   , 7.138   , 6.683   ,
#        2.776   , 9.132   , 4.814   , 4.933   , 6.479   , 4.406   ,
#        4.985   , 4.373   , 4.272   ])

# %%
[7, 17, 51, 34, 53, 45]
# Out:
# [7, 17, 51, 34, 53, 45]

# %%
encoder = load_model('./../data/nns/keep/encoder.h5')
decoder = load_model('./../data/nns/keep/decoder.h5')
model = load_model('./../data/nns/keep/ae_model.h5')

regressor = load_model    ('./../data/nns/keep/regressor.h5')
regressor_top = load_model('./../data/nns/keep/regressor_top.h5')
generator = load_model    ('./../data/nns/keep/generator.h5')
discriminator= load_model ('./../data/nns/keep/discriminator.h5')

pbar = ProgressBar()
max = 0.3

randS = []
rsquaredS = []
MAE_S = []
less20RE_perS = []
output_lenS = []
mean_RE_S = []
for rand in pbar(range(0, 10)):  
    N = 75
    n_sample = 100
    gen_error = []
    gen_smiles = []
    sample_ys = []
    preds = []
  
    predss_can = []
    gen_atoms_embedding = []
    gen_bonds_embedding = []

    regressor_top.trainable = False
    regressor.trainable = False
    generator.trainable = False
    discriminator.trainable = False

    np.random.seed(rand)

    pbar = ProgressBar()
    for hc in (pbar(range(n_sample))):
        try:
            # get it back to original of s_min to s_max
            sample_y = np.random.uniform(0, 2, size=[1,])
            #sample_y = hc
            #print (sample_y)
            sample_y = np.round(sample_y, 4)
            sample_y = sample_y * np.ones([N, ])
            sample_y_ = (sample_y - gap_min) / (gap_max - gap_min)
            sample_z = np.random.normal(0, 1, size = (N, 128))

            regressor_top.trainable = False
            regressor.trainable = False
            encoder.trainable = False
            decoder.trainable = False

            sample_atoms_embedding, sample_bonds_embedding = generator.predict([sample_z, sample_y_], verbose=0)
            dec_embedding = np.concatenate([sample_atoms_embedding, sample_bonds_embedding], axis = -1)

            softmax_smiles = decoder.predict(dec_embedding, verbose=0)[0]
            argmax_smiles = np.argmax(softmax_smiles, axis = 2)
            #print (argmax_smiles)

            #print ('shape argmax_smiles', argmax_smiles.shape)
            smiles = to_categorical(argmax_smiles, num_classes=27)
            
            SHAPE = list(smiles.shape) + [1] 
            
            #print ('shape line 767', SHAPE) 
            smiles = smiles.reshape(SHAPE)

            latent_encoder_atom, latent_encoder_bond, _ = encoder.predict([smiles], verbose=0)
            pred = regressor.predict([latent_encoder_atom, latent_encoder_bond], verbose=0).reshape([-1])
            pred = pred * (gap_max - gap_min) + gap_min

            gen_errors = np.abs((pred - sample_y) / sample_y).reshape([-1])


            smiles = decoder.predict(dec_embedding, verbose=0)[0]
            #print(smiles)
            smiles = np.argmax(smiles, axis = 2).reshape(smiles.shape[0], 40)
            

            generated_smiles = []
            
            for S in smiles:
                c_smiles = ''
                for s in S:
                    c_smiles += tokenizer[s]
                c_smiles = c_smiles.rstrip()
                #print (c_smiles)
                generated_smiles.append(c_smiles)
            generated_smiles = np.array(generated_smiles)
            #generated_smiles = generated_smiles [accurate]
            all_gen_smiles = []
            idx = []
            preds_can = []
            for i, smiles in enumerate(generated_smiles):
                all_gen_smiles.append(smiles[:-1])

                if ' ' in smiles[:-1]:
                    continue
                #m = Chem.MolFromSmiles(smiles[:-1], sanitize=False)
                m = Chem.MolFromSmiles(smiles[:-1], sanitize=True)
                if m is not None:
                    idx.append(i)
                    smiles_can = Chem.MolToSmiles(m, canonical=True)
                    smiles_can_dot = smiles_can + '.'
                    X_smiles0 = tokenizer_.texts_to_sequences([smiles_can_dot])
                    X_smiles1 = pad_sequences(X_smiles0, maxlen = 40, padding = 'post')
                    X_smiles2 = to_categorical(X_smiles1, num_classes=27)
                    latent_encoder_atom, latent_encoder_bond, _ = encoder.predict(X_smiles2, verbose=0)
                    pred_can = regressor.predict([latent_encoder_atom, latent_encoder_bond], verbose=0).reshape([-1])
                    pred_can = pred_can*11
                    preds_can.append(pred_can[0])


            idx = np.array(idx)
            all_gen_smiles = np.array(all_gen_smiles)
            #print ('all gen smiels shape', all_gen_smiles.shape)
            #print ('gen_errors shape', gen_errors.shape)
            #print (idx)
            gen_smiles.extend(list(all_gen_smiles[idx]))
            gen_error.extend(list(gen_errors[idx]))
            sample_ys.extend(list(sample_y[idx]))
            gen_atoms_embedding.extend(sample_atoms_embedding[idx])
            gen_bonds_embedding.extend(sample_bonds_embedding[idx])
            preds.extend(list(pred[idx]))
            predss_can.extend(list(preds_can))
        except:
            #print('Did not discover SMILES for HC: {}'.format(sample_y))
            pass    


    output = {}

    for i, s in enumerate (gen_smiles):
        ss = Chem.MolToSmiles(Chem.MolFromSmiles(s, sanitize=True), canonical=True)
        gen_smiles[i] = ss

    output['SMILES'] = gen_smiles
    output['des_gap'] = sample_ys
    # More accurate for regressor to predict gap from canonical SMILES
    output['pred_gap'] = predss_can
    #output['Err_pred_des'] = gen_error
    output['Err_pred_des'] = [abs(i- j)/i for i, j in zip(output['des_gap'], output['pred_gap'])]
    output = pd.DataFrame(output)
    output.reset_index(drop = True, inplace = True)
    if (sum (output['Err_pred_des']<= 0.2))/output.shape[0] > 0.0:
        output.to_csv ('./../experiments/regular/Initial_training{}.csv'.format(rand), index=False)
        print ((sum (output['Err_pred_des']<= 0.2))/output.shape[0] )

    ## Statistics  (# pred=True value, Des=prediction)
    # total # of samples
    N = len(predss_can)
    print ('random seed', rand)

    # Explained Variance R2 from sklearn.metrics.explained_variance_score
    explained_variance_R2_pred_des = explained_variance_score(output['des_gap'], output['pred_gap'])
    print ("explained_varice_R2_pred_des", explained_variance_R2_pred_des)
    rsquared = np.round (r2_score (output['des_gap'], output['pred_gap']), 4)
    print ("r squared r**2", rsquared)

    # mean absolute error 
    MAE_pred_des = np.round (mean_absolute_error(output['pred_gap'], output['des_gap']), 4)
    print ("MAE_pred_des", MAE_pred_des)
    # Fractioned MAE, more normalized
    Fractioned_MAE_pred_des = 0
    for pred, des in zip(output['pred_gap'], output['des_gap']):
        Fractioned_MAE_pred_des = Fractioned_MAE_pred_des +  abs(des-pred)/des
    Fractioned_MAE_pred_des = Fractioned_MAE_pred_des/N
    #print ("Fractioned MAE_pred_des", Fractioned_MAE_pred_des)

    # root mean squared error (RMSE), sqrt(sklearn ouputs MSE)
    RMSE_pred_des = mean_squared_error(output['pred_gap'], output['des_gap'])**0.5
    #print ("RMSE_pred_des", RMSE_pred_des)

    Fractioned_RMSE_pred_des = 0
    for pred, des in zip(output['pred_gap'], output['des_gap']):
        Fractioned_RMSE_pred_des = Fractioned_RMSE_pred_des + ((des-pred)/des)**2
    Fractioned_RMSE_pred_des = (Fractioned_RMSE_pred_des/N)**0.5
    #print ("Fractioned_RMSE_pred_des", Fractioned_RMSE_pred_des)

    # do not drop duplicate
    output2 = output.drop_duplicates(['SMILES'])
    output2.reset_index(drop = True, inplace = True)
    #output2.to_csv('./../experiments/regular/Initial_training_nodub.csv', index = False)
    """with open('gen_pickles.pickle', 'wb') as f:
        pickle.dump(gen_unique_pickles, f)
    """
    #print ('% < 20 RE NODUP', sum (output2['Err_pred_des'] < 0.2) / output2['Err_pred_des'].shape[0])
    less20RE_per = np.round ((sum(output['Err_pred_des'] <= 0.2) / output['Err_pred_des'].shape[0]), 4)
    print ('% < 20 RE', less20RE_per)
    output_len = len(output)
    explained_variance_R2_pred_des = explained_variance_score(output['des_gap'], output['pred_gap'])
    #print ("explained_varice_R2_pred_des", explained_variance_R2_pred_des)
    mean_RE = np.round (np.mean (output['Err_pred_des']), 4)
    print ('RE mean', mean_RE)

    randS.append(rand)
    rsquaredS.append(rsquared)
    MAE_S.append(MAE_pred_des)
    less20RE_perS.append(less20RE_per)
    mean_RE_S.append(mean_RE)
    output_lenS.append(output_len)

    if rsquared>max:
        good_rand = rand
        max = rsquared
        best_r2 = rsquared
        print ('best r2', best_r2)
        print ('best random seed', good_rand)
    
    tf.compat.v1.keras.backend.clear_session()

params = {}
params ['rand'] = randS
params ['r2'] = rsquaredS
params ['MAE'] = MAE_S
params ['less20RE_per'] = less20RE_perS
params ['Average_RE'] = mean_RE_S
params ['total_valid'] = output_lenS
params = pd.DataFrame(params)
params.reset_index(drop = True, inplace = True)
params.to_csv ('./gen_params.csv', index=False)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 100% |########################################################################|
#   0% |                                                                        |
# 0.15625
# random seed 0
# explained_varice_R2_pred_des -1.458606384317398
# r squared r**2 -6.2075
# MAE_pred_des 1.8615
# % < 20 RE 0.1562
# RE mean 0.7911
# 100% |########################################################################|
#   0% |                                                                        |
# 0.16393442622950818
# random seed 1
# explained_varice_R2_pred_des -2.0492614653084273
# r squared r**2 -6.3456
# MAE_pred_des 1.9429
# % < 20 RE 0.1639
# RE mean 0.8629
# 100% |########################################################################|
#   0% |                                                                        |
# 0.3877551020408163
# random seed 2
# explained_varice_R2_pred_des -3.4372382515392363
# r squared r**2 -6.2593
# MAE_pred_des 1.4352
# % < 20 RE 0.3878
# RE mean 0.5632
# 100% |########################################################################|
#   0% |                                                                        |
# 0.2054794520547945
# random seed 3
# explained_varice_R2_pred_des -1.4152736533634513
# r squared r**2 -5.2182
# MAE_pred_des 1.6769
# % < 20 RE 0.2055
# RE mean 0.777
# 100% |########################################################################|
#   0% |                                                                        |
# 0.2033898305084746
# random seed 4
# explained_varice_R2_pred_des -0.8278829378912969
# r squared r**2 -4.6129
# MAE_pred_des 1.8721
# % < 20 RE 0.2034
# RE mean 0.8987
# 100% |########################################################################|
#   0% |                                                                        |
# 0.23076923076923078
# random seed 5
# explained_varice_R2_pred_des -2.1562039176126038
# r squared r**2 -5.1021
# MAE_pred_des 1.7846
# % < 20 RE 0.2308
# RE mean 0.8248
# 100% |########################################################################|
#   0% |                                                                        |
# 0.26865671641791045
# random seed 6
# explained_varice_R2_pred_des -0.8585615273552551
# r squared r**2 -3.8263
# MAE_pred_des 1.5894
# % < 20 RE 0.2687
# RE mean 0.7763
# 100% |########################################################################|
#   0% |                                                                        |
# 0.2535211267605634
# random seed 7
# explained_varice_R2_pred_des -2.0274735586934365
# r squared r**2 -5.7061
# MAE_pred_des 1.7123
# % < 20 RE 0.2535
# RE mean 0.7477
# 100% |########################################################################|
#   0% |                                                                        |
# 0.21818181818181817
# random seed 8
# explained_varice_R2_pred_des -0.6378746170731551
# r squared r**2 -3.1439
# MAE_pred_des 1.5372
# % < 20 RE 0.2182
# RE mean 0.7268
# 100% |########################################################################|
# 100% |########################################################################|
# 0.13333333333333333
# random seed 9
# explained_varice_R2_pred_des -1.2968552609306832
# r squared r**2 -4.8665
# MAE_pred_des 1.7908
# % < 20 RE 0.1333
# RE mean 0.7474

# %%
output
# Out:
#                              SMILES  des_gap  pred_gap  Err_pred_des
# 0      CSC(ONc1ccc2nc-2s[nH]1)C1CC1   1.0311  4.681506      3.540302
# 1            COCc1ccc(CNNC(=N)S)n1O   2.3096  5.283394      1.287580
# 2             CNC(N)CCCC1CCCC1CCC#N   2.3096  7.345984      2.180631
# 3         CCC(C)=C1C=CC=CC=CC=CC=C1   1.2932  3.233274      1.500212
# 4          CCC1C=CN=CC=NC=CC=CCC1CC   3.5719  2.743321      0.231972
# ..                              ...      ...       ...           ...
# 70          C=C1OCC=C1CC(C)NCS(C)=O   3.5333  4.960634      0.403966
# 71  CCCCC1=C2CC1(C)C=CC=CCCONC2(C)C   3.5333  5.080145      0.437790
# 72        CSCCC1=CC=C(C)C1C(S)CN=CS   3.5333  2.884420      0.183647
# 73      O=NCCCSC1=NC=CN=NC=C1[SH]=O   3.6846  2.811198      0.237041
# 74     CNSC1=CC=CC2=CC=NNCC2CSN=C1C   2.4861  2.432070      0.021733
#
# [75 rows x 4 columns]

# %%
output
# Out:
#                          SMILES  des_gap   pred_gap  Err_pred_des
# 0          CC1CCCC(C)SCC(=O)CC1   5.8723   6.803613      0.158594
# 1           CCCNNCCCCCCCOC1CC1C   5.8723   6.948333      0.183239
# 2    CC1=CC=CCOCCC(C(C)CO)=C1CO   7.2233   5.645904      0.218376
# 3          CCC(CC)CCC1CCCCCCCC1   7.2233   9.848747      0.363469
# 4         CCCCCC=C(C)CCC1CCCCC1   7.2233   7.372819      0.020700
# ..                          ...      ...        ...           ...
# 274            CCCCC1CCCCCCCCC1   8.6614  10.089723      0.164907
# 275       CC(C)CCCC12CCCCCCC1N2   8.6614   8.791989      0.015077
# 276           C=CCCOCC(C)(C)COC   8.8382   7.766766      0.121228
# 277    CCC(OC)OC(C=C(C)CCCCO)OC   8.8382   6.852145      0.224713
# 278            CCC(O)CCCCCCCCCO   8.8382   8.583040      0.028870
#
# [279 rows x 4 columns]

# %%
np.mean (output['Err_pred_des'].loc[output['Err_pred_des']<0.2])
# Out:
# 0.10699985676419685

# %%
output['Err_des_pred'] =

# %%
output_screen = output.loc[output['Err_pred_des']<1]
less20RE_per = np.round ((sum(output_screen['Err_pred_des'] < 0.3) / output_screen['Err_pred_des'].shape[0]), 4)
less20RE_per
# Out:
# 0.8533

# %%
output['RE_pred_mean'] = [abs(i-j)/j for i,j in zip(output['pred_gap'], output['des_gap'])]

# %%
sns.histplot (output['RE_pred_mean'], bins=20)
# Out:
# <Axes: xlabel='RE_pred_mean', ylabel='Count'>

# %%
less20RE_per = np.round ((sum(output['RE_pred_mean'] < 0.2) / output['RE_pred_mean'].shape[0]), 4)
less20RE_per
# Out:
# 0.6364

# %%
try:
    print ('best r2', best_r2)
    print ('best random seed', good_rand)
except:
    pass
# Out:
# best r2 0.5874
# best random seed 7

# %%
plt.scatter (output['des_gap'].loc[output['Err_pred_des']<=0.7], output['pred_gap'].loc[output['Err_pred_des']<=0.7], s=5, color='red')
plt.scatter (output['des_gap'].loc[output['Err_pred_des']>0.7], output['pred_gap'].loc[output['Err_pred_des']>0.7], s=5, marker='*', color='blue')
#sns.scatterplot (x='des_gap', y='pred_gap', palette='Reds', s=15, edgecolor=None, data=output.loc[output['Err_pred_des']<0.7])
plt.plot([0, 11], [0, 11], '--k', )

# %%
sns.histplot (samples, stat='percent', bins=20)
sns.histplot (output['pred_gap'], stat='percent', bins=20)
# Out:
# <Axes: xlabel='pred_gap', ylabel='Percent'>
